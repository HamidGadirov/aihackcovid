# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sb

pd.set_option('display.max_columns', None)

data = pd.read_csv(r"owid-covid-data.csv")
data = data.sort_values('date', ascending=True)
data['date'] = pd.to_datetime(data['date'], format = '%Y-%m-%d')
data_NLD = data[data.iso_code=='NLD']
data_IND = data[data.iso_code=='IND']
data_USA = data[data.iso_code=='USA']
data_BRA = data[data.iso_code=='BRA']
data_NER = data[data.iso_code=='NER']

# %%
### New_cases in correlation to new_vaccinations_smoothed per country ###

# %%
dfn = data_NLD[['new_cases', 'new_vaccinations_smoothed']]
corr = dfn.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_333562f3_d678_11eb_852f_3c7c3f5d70b1row0_col0,#T_333562f3_d678_11eb_852f_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_333562f3_d678_11eb_852f_3c7c3f5d70b1row0_col1,#T_333562f3_d678_11eb_852f_3c7c3f5d70b1row1_col0{
#             background-color:  #9dbdff;
#             color:  #000000;
#         }</style><table id="T_333562f3_d678_11eb_852f_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >new_vaccinations_smoothed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_333562f3_d678_11eb_852f_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_333562f3_d678_11eb_852f_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
dft = data_NLD[['total_cases', 'new_vaccinations_smoothed']]
corr = dft.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_93aef074_d67a_11eb_a721_3c7c3f5d70b1row0_col0,#T_93aef074_d67a_11eb_a721_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_93aef074_d67a_11eb_a721_3c7c3f5d70b1row0_col1,#T_93aef074_d67a_11eb_a721_3c7c3f5d70b1row1_col0{
#             background-color:  #c0282f;
#             color:  #f1f1f1;
#         }</style><table id="T_93aef074_d67a_11eb_a721_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_cases</th>        <th class="col_heading level0 col1" >new_vaccinations_smoothed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_93aef074_d67a_11eb_a721_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >total_cases</th>
#                         <td id="T_93aef074_d67a_11eb_a721_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
data_NLD.plot(x="date", y=['new_cases', 'new_vaccinations_smoothed'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new vaccinations smoothed in the Netherlands\n', size=15);

plt.show()

# %%
data_NLD.plot(x="date", y=['total_cases', 'new_vaccinations_smoothed'])
plt.xticks(rotation=90)
plt.title('Plotting total cases and new vaccinations smoothed in the Netherlands\n', size=15);

plt.show()

# %%
dfn = data_IND[['new_cases', 'new_vaccinations_smoothed']]
corr = dfn.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_a319a7bc_d67a_11eb_b0e2_3c7c3f5d70b1row0_col0,#T_a319a7bc_d67a_11eb_b0e2_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_a319a7bc_d67a_11eb_b0e2_3c7c3f5d70b1row0_col1,#T_a319a7bc_d67a_11eb_b0e2_3c7c3f5d70b1row1_col0{
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }</style><table id="T_a319a7bc_d67a_11eb_b0e2_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >new_vaccinations_smoothed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a319a7bc_d67a_11eb_b0e2_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_a319a7bc_d67a_11eb_b0e2_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
dft = data_IND[['total_cases', 'new_vaccinations_smoothed']]
corr = dft.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_c3c170bc_d67a_11eb_a100_3c7c3f5d70b1row0_col0,#T_c3c170bc_d67a_11eb_a100_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_c3c170bc_d67a_11eb_a100_3c7c3f5d70b1row0_col1,#T_c3c170bc_d67a_11eb_a100_3c7c3f5d70b1row1_col0{
#             background-color:  #ee8468;
#             color:  #000000;
#         }</style><table id="T_c3c170bc_d67a_11eb_a100_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_cases</th>        <th class="col_heading level0 col1" >new_vaccinations_smoothed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c3c170bc_d67a_11eb_a100_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >total_cases</th>
#                         <td id="T_c3c170bc_d67a_11eb_a100_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
data_IND.plot(x="date", y=['new_cases', 'new_vaccinations_smoothed'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new vaccinations smoothed in India\n', size=15);
plt.show()

# %%
data_IND.plot(x="date", y=['total_cases', 'new_vaccinations_smoothed'])
plt.xticks(rotation=90)
plt.title('Plotting total cases and new vaccinations smoothed in India\n', size=15);
plt.show()

# %%
dfn = data_USA[['new_cases', 'new_vaccinations_smoothed']]
corr = dfn.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_8e51f783_d67c_11eb_8120_3c7c3f5d70b1row0_col0,#T_8e51f783_d67c_11eb_8120_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_8e51f783_d67c_11eb_8120_3c7c3f5d70b1row0_col1,#T_8e51f783_d67c_11eb_8120_3c7c3f5d70b1row1_col0{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }</style><table id="T_8e51f783_d67c_11eb_8120_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >new_vaccinations_smoothed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8e51f783_d67c_11eb_8120_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_8e51f783_d67c_11eb_8120_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
dft = data_USA[['total_cases', 'new_vaccinations_smoothed']]
corr = dft.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_97ece26d_d67c_11eb_ae23_3c7c3f5d70b1row0_col0,#T_97ece26d_d67c_11eb_ae23_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_97ece26d_d67c_11eb_ae23_3c7c3f5d70b1row0_col1,#T_97ece26d_d67c_11eb_ae23_3c7c3f5d70b1row1_col0{
#             background-color:  #eb7d62;
#             color:  #000000;
#         }</style><table id="T_97ece26d_d67c_11eb_ae23_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_cases</th>        <th class="col_heading level0 col1" >new_vaccinations_smoothed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_97ece26d_d67c_11eb_ae23_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >total_cases</th>
#                         <td id="T_97ece26d_d67c_11eb_ae23_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
data_USA.plot(x="date", y=['new_cases', 'new_vaccinations_smoothed'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new vaccinations smoothed in the USA\n', size=15);
plt.show()

# %%
data_USA.plot(x="date", y=['total_cases', 'new_vaccinations_smoothed'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new vaccinations smoothed in the USA\n', size=15);
plt.show()

# %%
dfn = data_BRA[['new_cases', 'new_vaccinations_smoothed']]
corr = dfn.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_b8277e11_d67c_11eb_9c95_3c7c3f5d70b1row0_col0,#T_b8277e11_d67c_11eb_9c95_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_b8277e11_d67c_11eb_9c95_3c7c3f5d70b1row0_col1,#T_b8277e11_d67c_11eb_9c95_3c7c3f5d70b1row1_col0{
#             background-color:  #f4c6af;
#             color:  #000000;
#         }</style><table id="T_b8277e11_d67c_11eb_9c95_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >new_vaccinations_smoothed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b8277e11_d67c_11eb_9c95_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_b8277e11_d67c_11eb_9c95_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
dft = data_BRA[['total_cases', 'new_vaccinations_smoothed']]
corr = dft.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_c0896ca4_d67c_11eb_a10c_3c7c3f5d70b1row0_col0,#T_c0896ca4_d67c_11eb_a10c_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_c0896ca4_d67c_11eb_a10c_3c7c3f5d70b1row0_col1,#T_c0896ca4_d67c_11eb_a10c_3c7c3f5d70b1row1_col0{
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }</style><table id="T_c0896ca4_d67c_11eb_a10c_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_cases</th>        <th class="col_heading level0 col1" >new_vaccinations_smoothed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c0896ca4_d67c_11eb_a10c_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >total_cases</th>
#                         <td id="T_c0896ca4_d67c_11eb_a10c_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
data_BRA.plot(x="date", y=['new_cases', 'new_vaccinations_smoothed'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new vaccinations smoothed in Brazil\n', size=15);
plt.show()

# %%
data_BRA.plot(x="date", y=['total_cases', 'new_vaccinations_smoothed'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new vaccinations smoothed in Brazil\n', size=15);
plt.show()

# %%
dfn = data_NER[['new_cases', 'new_vaccinations_smoothed']]
corr = dfn.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_d55c204d_d67c_11eb_9f76_3c7c3f5d70b1row0_col0,#T_d55c204d_d67c_11eb_9f76_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_d55c204d_d67c_11eb_9f76_3c7c3f5d70b1row0_col1,#T_d55c204d_d67c_11eb_9f76_3c7c3f5d70b1row1_col0{
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }</style><table id="T_d55c204d_d67c_11eb_9f76_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >new_vaccinations_smoothed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d55c204d_d67c_11eb_9f76_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_d55c204d_d67c_11eb_9f76_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
dft = data_NER[['total_cases', 'new_vaccinations_smoothed']]
corr = dft.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_de56aa2f_d67c_11eb_b075_3c7c3f5d70b1row0_col0,#T_de56aa2f_d67c_11eb_b075_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_de56aa2f_d67c_11eb_b075_3c7c3f5d70b1row0_col1,#T_de56aa2f_d67c_11eb_b075_3c7c3f5d70b1row1_col0{
#             background-color:  #ef886b;
#             color:  #000000;
#         }</style><table id="T_de56aa2f_d67c_11eb_b075_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_cases</th>        <th class="col_heading level0 col1" >new_vaccinations_smoothed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_de56aa2f_d67c_11eb_b075_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >total_cases</th>
#                         <td id="T_de56aa2f_d67c_11eb_b075_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
data_NER.plot(x="date", y=['new_cases', 'new_vaccinations_smoothed'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new vaccinations smoothed in Niger\n', size=15);
plt.show()

# %%
data_NER.plot(x="date", y=['total_cases', 'new_vaccinations_smoothed'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new vaccinations smoothed in Niger\n', size=15);
plt.show()

# %%
### New_deaths in correlation to new_vaccinations_smoothed per country ###

# %%
dfn = data_NLD[['new_deaths', 'new_vaccinations_smoothed']]
corr = dfn.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_3d02663e_d67d_11eb_af8d_3c7c3f5d70b1row0_col0,#T_3d02663e_d67d_11eb_af8d_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_3d02663e_d67d_11eb_af8d_3c7c3f5d70b1row0_col1,#T_3d02663e_d67d_11eb_af8d_3c7c3f5d70b1row1_col0{
#             background-color:  #688aef;
#             color:  #000000;
#         }</style><table id="T_3d02663e_d67d_11eb_af8d_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_deaths</th>        <th class="col_heading level0 col1" >new_vaccinations_smoothed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3d02663e_d67d_11eb_af8d_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_deaths</th>
#                         <td id="T_3d02663e_d67d_11eb_af8d_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
dft = data_NLD[['total_deaths', 'new_vaccinations_smoothed']]
corr = dft.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_70f7513e_d67d_11eb_8b6a_3c7c3f5d70b1row0_col0,#T_70f7513e_d67d_11eb_8b6a_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_70f7513e_d67d_11eb_8b6a_3c7c3f5d70b1row0_col1,#T_70f7513e_d67d_11eb_8b6a_3c7c3f5d70b1row1_col0{
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }</style><table id="T_70f7513e_d67d_11eb_8b6a_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_deaths</th>        <th class="col_heading level0 col1" >new_vaccinations_smoothed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_70f7513e_d67d_11eb_8b6a_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >total_deaths</th>
#                         <td id="T_70f7513e_d67d_11eb_8b6a_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
data_NLD.plot(x="date", y=['new_deaths', 'new_vaccinations_smoothed'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in the Netherlands\n', size=15);
plt.show()

# %%
data_NLD.plot(x="date", y=['total_deaths', 'new_vaccinations_smoothed'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in the Netherlands\n', size=15);
plt.show()

# %%
df = data_IND[['new_deaths', 'new_vaccinations_smoothed']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_8788d7ff_d67d_11eb_9edd_3c7c3f5d70b1row0_col0,#T_8788d7ff_d67d_11eb_9edd_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_8788d7ff_d67d_11eb_9edd_3c7c3f5d70b1row0_col1,#T_8788d7ff_d67d_11eb_9edd_3c7c3f5d70b1row1_col0{
#             background-color:  #f6a586;
#             color:  #000000;
#         }</style><table id="T_8788d7ff_d67d_11eb_9edd_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_deaths</th>        <th class="col_heading level0 col1" >new_vaccinations_smoothed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8788d7ff_d67d_11eb_9edd_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_deaths</th>
#                         <td id="T_8788d7ff_d67d_11eb_9edd_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
df = data_IND[['total_deaths', 'new_vaccinations_smoothed']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_8faac9a6_d67d_11eb_926d_3c7c3f5d70b1row0_col0,#T_8faac9a6_d67d_11eb_926d_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_8faac9a6_d67d_11eb_926d_3c7c3f5d70b1row0_col1,#T_8faac9a6_d67d_11eb_926d_3c7c3f5d70b1row1_col0{
#             background-color:  #ee8669;
#             color:  #000000;
#         }</style><table id="T_8faac9a6_d67d_11eb_926d_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_deaths</th>        <th class="col_heading level0 col1" >new_vaccinations_smoothed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8faac9a6_d67d_11eb_926d_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >total_deaths</th>
#                         <td id="T_8faac9a6_d67d_11eb_926d_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
data_IND.plot(x="date", y=['new_deaths', 'new_vaccinations_smoothed'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in India\n', size=15);
plt.show()

# %%
data_IND.plot(x="date", y=['total_deaths', 'new_vaccinations_smoothed'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in India\n', size=15);
plt.show()

# %%
df = data_USA[['new_deaths', 'new_vaccinations_smoothed']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_c37d0a05_d67d_11eb_8fc5_3c7c3f5d70b1row0_col0,#T_c37d0a05_d67d_11eb_8fc5_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_c37d0a05_d67d_11eb_8fc5_3c7c3f5d70b1row0_col1,#T_c37d0a05_d67d_11eb_8fc5_3c7c3f5d70b1row1_col0{
#             background-color:  #8badfd;
#             color:  #000000;
#         }</style><table id="T_c37d0a05_d67d_11eb_8fc5_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_deaths</th>        <th class="col_heading level0 col1" >new_vaccinations_smoothed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c37d0a05_d67d_11eb_8fc5_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_deaths</th>
#                         <td id="T_c37d0a05_d67d_11eb_8fc5_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
df = data_USA[['total_deaths', 'new_vaccinations_smoothed']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_cace1885_d67d_11eb_8aae_3c7c3f5d70b1row0_col0,#T_cace1885_d67d_11eb_8aae_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_cace1885_d67d_11eb_8aae_3c7c3f5d70b1row0_col1,#T_cace1885_d67d_11eb_8aae_3c7c3f5d70b1row1_col0{
#             background-color:  #e9785d;
#             color:  #000000;
#         }</style><table id="T_cace1885_d67d_11eb_8aae_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_deaths</th>        <th class="col_heading level0 col1" >new_vaccinations_smoothed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cace1885_d67d_11eb_8aae_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >total_deaths</th>
#                         <td id="T_cace1885_d67d_11eb_8aae_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
data_USA.plot(x="date", y=['new_deaths', 'new_vaccinations_smoothed'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in the USA\n', size=15);
plt.show()

# %%
data_USA.plot(x="date", y=['total_deaths', 'new_vaccinations_smoothed'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in the USA\n', size=15);
plt.show()

# %%
df = data_BRA[['new_deaths', 'new_vaccinations_smoothed']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_dc3603f4_d67d_11eb_88e5_3c7c3f5d70b1row0_col0,#T_dc3603f4_d67d_11eb_88e5_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_dc3603f4_d67d_11eb_88e5_3c7c3f5d70b1row0_col1,#T_dc3603f4_d67d_11eb_88e5_3c7c3f5d70b1row1_col0{
#             background-color:  #f7b396;
#             color:  #000000;
#         }</style><table id="T_dc3603f4_d67d_11eb_88e5_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_deaths</th>        <th class="col_heading level0 col1" >new_vaccinations_smoothed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dc3603f4_d67d_11eb_88e5_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_deaths</th>
#                         <td id="T_dc3603f4_d67d_11eb_88e5_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
df = data_BRA[['total_deaths', 'new_vaccinations_smoothed']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_e73c354e_d67d_11eb_86b4_3c7c3f5d70b1row0_col0,#T_e73c354e_d67d_11eb_86b4_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_e73c354e_d67d_11eb_86b4_3c7c3f5d70b1row0_col1,#T_e73c354e_d67d_11eb_86b4_3c7c3f5d70b1row1_col0{
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }</style><table id="T_e73c354e_d67d_11eb_86b4_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_deaths</th>        <th class="col_heading level0 col1" >new_vaccinations_smoothed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e73c354e_d67d_11eb_86b4_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >total_deaths</th>
#                         <td id="T_e73c354e_d67d_11eb_86b4_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
data_BRA.plot(x="date", y=['new_deaths', 'new_vaccinations_smoothed'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in Brazil\n', size=15);
plt.show()

# %%
data_BRA.plot(x="date", y=['total_deaths', 'new_vaccinations_smoothed'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in Brazil\n', size=15);
plt.show()

# %%
df = data_NER[['new_deaths', 'new_vaccinations_smoothed']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_fd2b4e95_d67d_11eb_8f53_3c7c3f5d70b1row0_col0,#T_fd2b4e95_d67d_11eb_8f53_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_fd2b4e95_d67d_11eb_8f53_3c7c3f5d70b1row0_col1,#T_fd2b4e95_d67d_11eb_8f53_3c7c3f5d70b1row1_col0{
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }</style><table id="T_fd2b4e95_d67d_11eb_8f53_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_deaths</th>        <th class="col_heading level0 col1" >new_vaccinations_smoothed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fd2b4e95_d67d_11eb_8f53_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_deaths</th>
#                         <td id="T_fd2b4e95_d67d_11eb_8f53_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
df = data_NER[['total_deaths', 'new_vaccinations_smoothed']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_03761cbe_d67e_11eb_97cf_3c7c3f5d70b1row0_col0,#T_03761cbe_d67e_11eb_97cf_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_03761cbe_d67e_11eb_97cf_3c7c3f5d70b1row0_col1,#T_03761cbe_d67e_11eb_97cf_3c7c3f5d70b1row1_col0{
#             background-color:  #e8765c;
#             color:  #000000;
#         }</style><table id="T_03761cbe_d67e_11eb_97cf_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_deaths</th>        <th class="col_heading level0 col1" >new_vaccinations_smoothed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_03761cbe_d67e_11eb_97cf_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >total_deaths</th>
#                         <td id="T_03761cbe_d67e_11eb_97cf_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
data_NER.plot(x="date", y=['new_deaths', 'new_vaccinations_smoothed'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in Niger\n', size=15);
plt.show()

# %%
data_NER.plot(x="date", y=['total_deaths', 'new_vaccinations_smoothed'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in Niger\n', size=15);
plt.show()

# %%
### New_cases in correlation to icu_patients per country ###

# %%
df = data_NLD[['new_cases', 'icu_patients']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_1ed937d6_d67e_11eb_a2d9_3c7c3f5d70b1row0_col0,#T_1ed937d6_d67e_11eb_a2d9_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_1ed937d6_d67e_11eb_a2d9_3c7c3f5d70b1row0_col1,#T_1ed937d6_d67e_11eb_a2d9_3c7c3f5d70b1row1_col0{
#             background-color:  #f7a688;
#             color:  #000000;
#         }</style><table id="T_1ed937d6_d67e_11eb_a2d9_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >icu_patients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1ed937d6_d67e_11eb_a2d9_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_1ed937d6_d67e_11eb_a2d9_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
df = data_NLD[['total_cases', 'icu_patients']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_26400000_d67e_11eb_ad66_3c7c3f5d70b1row0_col0,#T_26400000_d67e_11eb_ad66_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_26400000_d67e_11eb_ad66_3c7c3f5d70b1row0_col1,#T_26400000_d67e_11eb_ad66_3c7c3f5d70b1row1_col0{
#             background-color:  #f7af91;
#             color:  #000000;
#         }</style><table id="T_26400000_d67e_11eb_ad66_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_cases</th>        <th class="col_heading level0 col1" >icu_patients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_26400000_d67e_11eb_ad66_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >total_cases</th>
#                         <td id="T_26400000_d67e_11eb_ad66_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
data_NLD.plot(x="date", y=['new_cases', 'icu_patients'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in the Netherlands\n', size=15);
plt.show()

# %%
data_NLD.plot(x="date", y=['total_cases', 'icu_patients'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in the Netherlands\n', size=15);
plt.show()

# %%
df = data_USA[['new_cases', 'icu_patients']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_4c306e5a_d67e_11eb_9447_3c7c3f5d70b1row0_col0,#T_4c306e5a_d67e_11eb_9447_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_4c306e5a_d67e_11eb_9447_3c7c3f5d70b1row0_col1,#T_4c306e5a_d67e_11eb_9447_3c7c3f5d70b1row1_col0{
#             background-color:  #c32e31;
#             color:  #f1f1f1;
#         }</style><table id="T_4c306e5a_d67e_11eb_9447_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >icu_patients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4c306e5a_d67e_11eb_9447_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_4c306e5a_d67e_11eb_9447_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
df = data_USA[['total_cases', 'icu_patients']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_514becba_d67e_11eb_ac28_3c7c3f5d70b1row0_col0,#T_514becba_d67e_11eb_ac28_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_514becba_d67e_11eb_ac28_3c7c3f5d70b1row0_col1,#T_514becba_d67e_11eb_ac28_3c7c3f5d70b1row1_col0{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }</style><table id="T_514becba_d67e_11eb_ac28_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_cases</th>        <th class="col_heading level0 col1" >icu_patients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_514becba_d67e_11eb_ac28_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >total_cases</th>
#                         <td id="T_514becba_d67e_11eb_ac28_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
data_USA.plot(x="date", y=['new_cases', 'icu_patients'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in the USA\n', size=15);
plt.show()

# %%
data_USA.plot(x="date", y=['total_cases', 'icu_patients'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in the USA\n', size=15);
plt.show()

# %%
### New_deaths in correlation to icu_patients per country ###

# %%
df = data_NLD[['new_deaths', 'icu_patients']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_607baea2_d67e_11eb_b611_3c7c3f5d70b1row0_col0,#T_607baea2_d67e_11eb_b611_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_607baea2_d67e_11eb_b611_3c7c3f5d70b1row0_col1,#T_607baea2_d67e_11eb_b611_3c7c3f5d70b1row1_col0{
#             background-color:  #e0654f;
#             color:  #000000;
#         }</style><table id="T_607baea2_d67e_11eb_b611_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_deaths</th>        <th class="col_heading level0 col1" >icu_patients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_607baea2_d67e_11eb_b611_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_deaths</th>
#                         <td id="T_607baea2_d67e_11eb_b611_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
df = data_NLD[['total_deaths', 'icu_patients']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_69531b1d_d67e_11eb_bd41_3c7c3f5d70b1row0_col0,#T_69531b1d_d67e_11eb_bd41_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_69531b1d_d67e_11eb_bd41_3c7c3f5d70b1row0_col1,#T_69531b1d_d67e_11eb_bd41_3c7c3f5d70b1row1_col0{
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }</style><table id="T_69531b1d_d67e_11eb_bd41_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_deaths</th>        <th class="col_heading level0 col1" >icu_patients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_69531b1d_d67e_11eb_bd41_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >total_deaths</th>
#                         <td id="T_69531b1d_d67e_11eb_bd41_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
data_NLD.plot(x="date", y=['new_deaths', 'icu_patients'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in the Netherlands\n', size=15);
plt.show()

# %%
data_NLD.plot(x="date", y=['total_deaths', 'icu_patients'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in the Netherlands\n', size=15);
plt.show()

# %%
df = data_USA[['new_deaths', 'icu_patients']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_7c60ddd1_d67e_11eb_a61d_3c7c3f5d70b1row0_col0,#T_7c60ddd1_d67e_11eb_a61d_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_7c60ddd1_d67e_11eb_a61d_3c7c3f5d70b1row0_col1,#T_7c60ddd1_d67e_11eb_a61d_3c7c3f5d70b1row1_col0{
#             background-color:  #d44e41;
#             color:  #000000;
#         }</style><table id="T_7c60ddd1_d67e_11eb_a61d_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_deaths</th>        <th class="col_heading level0 col1" >icu_patients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7c60ddd1_d67e_11eb_a61d_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_deaths</th>
#                         <td id="T_7c60ddd1_d67e_11eb_a61d_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
df = data_USA[['total_deaths', 'icu_patients']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_814aeae6_d67e_11eb_b3fa_3c7c3f5d70b1row0_col0,#T_814aeae6_d67e_11eb_b3fa_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_814aeae6_d67e_11eb_b3fa_3c7c3f5d70b1row0_col1,#T_814aeae6_d67e_11eb_b3fa_3c7c3f5d70b1row1_col0{
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }</style><table id="T_814aeae6_d67e_11eb_b3fa_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_deaths</th>        <th class="col_heading level0 col1" >icu_patients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_814aeae6_d67e_11eb_b3fa_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >total_deaths</th>
#                         <td id="T_814aeae6_d67e_11eb_b3fa_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
data_USA.plot(x="date", y=['new_deaths', 'icu_patients'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in the USA\n', size=15);
plt.show()

# %%
data_USA.plot(x="date", y=['total_deaths', 'icu_patients'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in the USA\n', size=15);
plt.show()

# %%
### New_cases in correlation to stringency_index per country ###

# %%
df = data_NLD[['new_cases', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_902af9e1_d67e_11eb_901b_3c7c3f5d70b1row0_col0,#T_902af9e1_d67e_11eb_901b_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_902af9e1_d67e_11eb_901b_3c7c3f5d70b1row0_col1,#T_902af9e1_d67e_11eb_901b_3c7c3f5d70b1row1_col0{
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }</style><table id="T_902af9e1_d67e_11eb_901b_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_902af9e1_d67e_11eb_901b_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_902af9e1_d67e_11eb_901b_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
df = data_NLD[['total_cases', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_95e9413e_d67e_11eb_9398_3c7c3f5d70b1row0_col0,#T_95e9413e_d67e_11eb_9398_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_95e9413e_d67e_11eb_9398_3c7c3f5d70b1row0_col1,#T_95e9413e_d67e_11eb_9398_3c7c3f5d70b1row1_col0{
#             background-color:  #f6a283;
#             color:  #000000;
#         }</style><table id="T_95e9413e_d67e_11eb_9398_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_cases</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_95e9413e_d67e_11eb_9398_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >total_cases</th>
#                         <td id="T_95e9413e_d67e_11eb_9398_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
data_NLD.plot(x="date", y=['new_cases'])
plt.title('Plotting new cases per date in the Netherlands\n', size=15);
data_NLD.plot(x='date', y=['stringency_index'])
plt.title('Plotting stringency index per date in the Netherlands\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
data_NLD.plot(x="date", y=['total_cases'])
plt.title('Plotting new cases per date in the Netherlands\n', size=15);
data_NLD.plot(x='date', y=['stringency_index'])
plt.title('Plotting stringency index per date in the Netherlands\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
df = data_IND[['new_cases', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_afc4d153_d67e_11eb_87d2_3c7c3f5d70b1row0_col0,#T_afc4d153_d67e_11eb_87d2_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_afc4d153_d67e_11eb_87d2_3c7c3f5d70b1row0_col1,#T_afc4d153_d67e_11eb_87d2_3c7c3f5d70b1row1_col0{
#             background-color:  #efcfbf;
#             color:  #000000;
#         }</style><table id="T_afc4d153_d67e_11eb_87d2_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_afc4d153_d67e_11eb_87d2_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_afc4d153_d67e_11eb_87d2_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
df = data_IND[['total_cases', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_b5ebe6fd_d67e_11eb_8da4_3c7c3f5d70b1row0_col0,#T_b5ebe6fd_d67e_11eb_8da4_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_b5ebe6fd_d67e_11eb_8da4_3c7c3f5d70b1row0_col1,#T_b5ebe6fd_d67e_11eb_8da4_3c7c3f5d70b1row1_col0{
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }</style><table id="T_b5ebe6fd_d67e_11eb_8da4_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_cases</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b5ebe6fd_d67e_11eb_8da4_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >total_cases</th>
#                         <td id="T_b5ebe6fd_d67e_11eb_8da4_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
data_IND.plot(x="date", y=['new_cases'])
plt.title('Plotting new cases per date in India\n', size=15);
data_IND.plot(x='date', y=['stringency_index'])
plt.title('Plotting stringency index per date in India\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
data_IND.plot(x="date", y=['total_cases'])
plt.title('Plotting new cases per date in India\n', size=15);
data_IND.plot(x='date', y=['stringency_index'])
plt.title('Plotting stringency index per date in India\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
df = data_USA[['new_cases', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_a45bb32a_d675_11eb_a4dc_3c7c3f5d70b1row0_col0,#T_a45bb32a_d675_11eb_a4dc_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_a45bb32a_d675_11eb_a4dc_3c7c3f5d70b1row0_col1,#T_a45bb32a_d675_11eb_a4dc_3c7c3f5d70b1row1_col0{
#             background-color:  #f6a586;
#             color:  #000000;
#         }</style><table id="T_a45bb32a_d675_11eb_a4dc_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a45bb32a_d675_11eb_a4dc_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_a45bb32a_d675_11eb_a4dc_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
df = data_USA[['total_cases', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_dfc56e8b_d67e_11eb_b9c2_3c7c3f5d70b1row0_col0,#T_dfc56e8b_d67e_11eb_b9c2_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_dfc56e8b_d67e_11eb_b9c2_3c7c3f5d70b1row0_col1,#T_dfc56e8b_d67e_11eb_b9c2_3c7c3f5d70b1row1_col0{
#             background-color:  #ecd3c5;
#             color:  #000000;
#         }</style><table id="T_dfc56e8b_d67e_11eb_b9c2_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_cases</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dfc56e8b_d67e_11eb_b9c2_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >total_cases</th>
#                         <td id="T_dfc56e8b_d67e_11eb_b9c2_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
data_USA.plot(x="date", y=['new_cases'])
plt.title('Plotting new cases per date in the USA\n', size=15);
data_USA.plot(x='date', y=['stringency_index'])
plt.title('Plotting stringency index per date in the USA\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
data_USA.plot(x="date", y=['total_cases'])
plt.title('Plotting new cases per date in the USA\n', size=15);
data_USA.plot(x='date', y=['stringency_index'])
plt.title('Plotting stringency index per date in the USA\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
df = data_BRA[['new_cases', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_a81580c2_d675_11eb_9f77_3c7c3f5d70b1row0_col0,#T_a81580c2_d675_11eb_9f77_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_a81580c2_d675_11eb_9f77_3c7c3f5d70b1row0_col1,#T_a81580c2_d675_11eb_9f77_3c7c3f5d70b1row1_col0{
#             background-color:  #ead5c9;
#             color:  #000000;
#         }</style><table id="T_a81580c2_d675_11eb_9f77_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a81580c2_d675_11eb_9f77_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_a81580c2_d675_11eb_9f77_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
df = data_BRA[['total_cases', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_f49117a8_d67e_11eb_aaf3_3c7c3f5d70b1row0_col0,#T_f49117a8_d67e_11eb_aaf3_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_f49117a8_d67e_11eb_aaf3_3c7c3f5d70b1row0_col1,#T_f49117a8_d67e_11eb_aaf3_3c7c3f5d70b1row1_col0{
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }</style><table id="T_f49117a8_d67e_11eb_aaf3_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_cases</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f49117a8_d67e_11eb_aaf3_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >total_cases</th>
#                         <td id="T_f49117a8_d67e_11eb_aaf3_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
data_BRA.plot(x="date", y=['new_cases'])
plt.title('Plotting new cases per date in Brazil\n', size=15);
data_BRA.plot(x='date', y=['stringency_index'])
plt.title('Plotting stringency index per date in Brazil\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
data_BRA.plot(x="date", y=['total_cases'])
plt.title('Plotting new cases per date in Brazil\n', size=15);
data_BRA.plot(x='date', y=['stringency_index'])
plt.title('Plotting stringency index per date in Brazil\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
df = data_NER[['new_cases', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_ab06fff8_d675_11eb_9745_3c7c3f5d70b1row0_col0,#T_ab06fff8_d675_11eb_9745_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_ab06fff8_d675_11eb_9745_3c7c3f5d70b1row0_col1,#T_ab06fff8_d675_11eb_9745_3c7c3f5d70b1row1_col0{
#             background-color:  #f1cdba;
#             color:  #000000;
#         }</style><table id="T_ab06fff8_d675_11eb_9745_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ab06fff8_d675_11eb_9745_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_ab06fff8_d675_11eb_9745_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
df = data_NER[['total_cases', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_070b918d_d67f_11eb_a98a_3c7c3f5d70b1row0_col0,#T_070b918d_d67f_11eb_a98a_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_070b918d_d67f_11eb_a98a_3c7c3f5d70b1row0_col1,#T_070b918d_d67f_11eb_a98a_3c7c3f5d70b1row1_col0{
#             background-color:  #d1dae9;
#             color:  #000000;
#         }</style><table id="T_070b918d_d67f_11eb_a98a_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_cases</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_070b918d_d67f_11eb_a98a_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >total_cases</th>
#                         <td id="T_070b918d_d67f_11eb_a98a_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
data_NER.plot(x="date", y=['new_cases'])
plt.title('Plotting new cases per date in Niger\n', size=15);
data_NER.plot(x='date', y=['stringency_index'])
plt.title('Plotting stringency index per date in Niger\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
data_NER.plot(x="date", y=['total_cases'])
plt.title('Plotting new cases per date in Niger\n', size=15);
data_NER.plot(x='date', y=['stringency_index'])
plt.title('Plotting stringency index per date in Niger\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
### New_deaths in correlation to stringency_index per country ###

# %%
df = data_NLD[['new_deaths', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_ae210669_d675_11eb_9eb5_3c7c3f5d70b1row0_col0,#T_ae210669_d675_11eb_9eb5_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_ae210669_d675_11eb_9eb5_3c7c3f5d70b1row0_col1,#T_ae210669_d675_11eb_9eb5_3c7c3f5d70b1row1_col0{
#             background-color:  #f08b6e;
#             color:  #000000;
#         }</style><table id="T_ae210669_d675_11eb_9eb5_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_deaths</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ae210669_d675_11eb_9eb5_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_deaths</th>
#                         <td id="T_ae210669_d675_11eb_9eb5_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
df = data_NLD[['total_deaths', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_35fefafd_d67f_11eb_b2d1_3c7c3f5d70b1row0_col0,#T_35fefafd_d67f_11eb_b2d1_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_35fefafd_d67f_11eb_b2d1_3c7c3f5d70b1row0_col1,#T_35fefafd_d67f_11eb_b2d1_3c7c3f5d70b1row1_col0{
#             background-color:  #f7a889;
#             color:  #000000;
#         }</style><table id="T_35fefafd_d67f_11eb_b2d1_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_deaths</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_35fefafd_d67f_11eb_b2d1_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >total_deaths</th>
#                         <td id="T_35fefafd_d67f_11eb_b2d1_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
data_NLD.plot(x="date", y=['new_deaths'])
plt.title('Plotting new deaths per date in the Netherlands\n', size=15);
data_NLD.plot(x='date', y=['stringency_index'])
plt.title('Plotting stringency index per date in the Netherlands\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
df = data_IND[['new_deaths', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_b0a40fb0_d675_11eb_af5c_3c7c3f5d70b1row0_col0,#T_b0a40fb0_d675_11eb_af5c_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_b0a40fb0_d675_11eb_af5c_3c7c3f5d70b1row0_col1,#T_b0a40fb0_d675_11eb_af5c_3c7c3f5d70b1row1_col0{
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }</style><table id="T_b0a40fb0_d675_11eb_af5c_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_deaths</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b0a40fb0_d675_11eb_af5c_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_deaths</th>
#                         <td id="T_b0a40fb0_d675_11eb_af5c_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
df = data_IND[['total_deaths', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_5e89eb46_d67f_11eb_a3e3_3c7c3f5d70b1row0_col0,#T_5e89eb46_d67f_11eb_a3e3_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_5e89eb46_d67f_11eb_a3e3_3c7c3f5d70b1row0_col1,#T_5e89eb46_d67f_11eb_a3e3_3c7c3f5d70b1row1_col0{
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }</style><table id="T_5e89eb46_d67f_11eb_a3e3_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_deaths</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5e89eb46_d67f_11eb_a3e3_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >total_deaths</th>
#                         <td id="T_5e89eb46_d67f_11eb_a3e3_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
data_IND.plot(x="date", y=['new_deaths'])
plt.title('Plotting new deaths per date in India\n', size=15);
data_IND.plot(x='date', y=['stringency_index'])
plt.title('Plotting stringency index per date in India\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
df = data_USA[['new_deaths', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_b25efa71_d675_11eb_abd7_3c7c3f5d70b1row0_col0,#T_b25efa71_d675_11eb_abd7_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_b25efa71_d675_11eb_abd7_3c7c3f5d70b1row0_col1,#T_b25efa71_d675_11eb_abd7_3c7c3f5d70b1row1_col0{
#             background-color:  #f59d7e;
#             color:  #000000;
#         }</style><table id="T_b25efa71_d675_11eb_abd7_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_deaths</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b25efa71_d675_11eb_abd7_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_deaths</th>
#                         <td id="T_b25efa71_d675_11eb_abd7_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
df = data_USA[['total_deaths', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_65f42e0c_d67f_11eb_b4f8_3c7c3f5d70b1row0_col0,#T_65f42e0c_d67f_11eb_b4f8_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_65f42e0c_d67f_11eb_b4f8_3c7c3f5d70b1row0_col1,#T_65f42e0c_d67f_11eb_b4f8_3c7c3f5d70b1row1_col0{
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }</style><table id="T_65f42e0c_d67f_11eb_b4f8_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_deaths</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_65f42e0c_d67f_11eb_b4f8_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >total_deaths</th>
#                         <td id="T_65f42e0c_d67f_11eb_b4f8_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
data_USA.plot(x="date", y=['new_deaths'])
plt.title('Plotting new deaths per date in the USA\n', size=15);
data_USA.plot(x='date', y=['stringency_index'])
plt.title('Plotting stringency index per date in the USA\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
df = data_BRA[['new_deaths', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_b40cc945_d675_11eb_ac0c_3c7c3f5d70b1row0_col0,#T_b40cc945_d675_11eb_ac0c_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_b40cc945_d675_11eb_ac0c_3c7c3f5d70b1row0_col1,#T_b40cc945_d675_11eb_ac0c_3c7c3f5d70b1row1_col0{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }</style><table id="T_b40cc945_d675_11eb_ac0c_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_deaths</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b40cc945_d675_11eb_ac0c_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_deaths</th>
#                         <td id="T_b40cc945_d675_11eb_ac0c_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
df = data_BRA[['total_deaths', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_6f896b84_d67f_11eb_90e6_3c7c3f5d70b1row0_col0,#T_6f896b84_d67f_11eb_90e6_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_6f896b84_d67f_11eb_90e6_3c7c3f5d70b1row0_col1,#T_6f896b84_d67f_11eb_90e6_3c7c3f5d70b1row1_col0{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }</style><table id="T_6f896b84_d67f_11eb_90e6_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_deaths</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6f896b84_d67f_11eb_90e6_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >total_deaths</th>
#                         <td id="T_6f896b84_d67f_11eb_90e6_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
data_BRA.plot(x="date", y=['new_deaths'])
plt.title('Plotting new deaths per date in Brazil\n', size=15);
data_BRA.plot(x='date', y=['stringency_index'])
plt.title('Plotting stringency index per date in Brazil\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
df = data_NER[['new_deaths', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_b625a8c0_d675_11eb_902a_3c7c3f5d70b1row0_col0,#T_b625a8c0_d675_11eb_902a_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_b625a8c0_d675_11eb_902a_3c7c3f5d70b1row0_col1,#T_b625a8c0_d675_11eb_902a_3c7c3f5d70b1row1_col0{
#             background-color:  #f6bda2;
#             color:  #000000;
#         }</style><table id="T_b625a8c0_d675_11eb_902a_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_deaths</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b625a8c0_d675_11eb_902a_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_deaths</th>
#                         <td id="T_b625a8c0_d675_11eb_902a_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
df = data_NER[['total_deaths', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_775216b1_d67f_11eb_acef_3c7c3f5d70b1row0_col0,#T_775216b1_d67f_11eb_acef_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_775216b1_d67f_11eb_acef_3c7c3f5d70b1row0_col1,#T_775216b1_d67f_11eb_acef_3c7c3f5d70b1row1_col0{
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }</style><table id="T_775216b1_d67f_11eb_acef_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_deaths</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_775216b1_d67f_11eb_acef_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >total_deaths</th>
#                         <td id="T_775216b1_d67f_11eb_acef_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
data_NER.plot(x="date", y=['new_deaths'])
plt.title('Plotting new deaths per date in Niger\n', size=15);
data_NER.plot(x='date', y=['stringency_index'])
plt.title('Plotting stringency index per date in Niger\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
### New_cases in correlation to hosp_patients per country ###

# %%
df = data_NLD[['new_cases', 'hosp_patients']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_b85e1399_d675_11eb_9686_3c7c3f5d70b1row0_col0,#T_b85e1399_d675_11eb_9686_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_b85e1399_d675_11eb_9686_3c7c3f5d70b1row0_col1,#T_b85e1399_d675_11eb_9686_3c7c3f5d70b1row1_col0{
#             background-color:  #f29274;
#             color:  #000000;
#         }</style><table id="T_b85e1399_d675_11eb_9686_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >hosp_patients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b85e1399_d675_11eb_9686_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_b85e1399_d675_11eb_9686_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
df = data_NLD[['total_cases', 'hosp_patients']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_7ef5d418_d67f_11eb_b998_3c7c3f5d70b1row0_col0,#T_7ef5d418_d67f_11eb_b998_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_7ef5d418_d67f_11eb_b998_3c7c3f5d70b1row0_col1,#T_7ef5d418_d67f_11eb_b998_3c7c3f5d70b1row1_col0{
#             background-color:  #f7b89c;
#             color:  #000000;
#         }</style><table id="T_7ef5d418_d67f_11eb_b998_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_cases</th>        <th class="col_heading level0 col1" >hosp_patients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7ef5d418_d67f_11eb_b998_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >total_cases</th>
#                         <td id="T_7ef5d418_d67f_11eb_b998_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
data_NLD.plot(x="date", y=['new_cases', 'hosp_patients'])
plt.title('Plotting new cases and hospital patients in the Netherlands\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
df = data_USA[['new_cases', 'hosp_patients']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_bd8b9b8c_d675_11eb_9776_3c7c3f5d70b1row0_col0,#T_bd8b9b8c_d675_11eb_9776_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_bd8b9b8c_d675_11eb_9776_3c7c3f5d70b1row0_col1,#T_bd8b9b8c_d675_11eb_9776_3c7c3f5d70b1row1_col0{
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }</style><table id="T_bd8b9b8c_d675_11eb_9776_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >hosp_patients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bd8b9b8c_d675_11eb_9776_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_bd8b9b8c_d675_11eb_9776_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
df = data_USA[['total_cases', 'hosp_patients']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_85e295fe_d67f_11eb_bec6_3c7c3f5d70b1row0_col0,#T_85e295fe_d67f_11eb_bec6_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_85e295fe_d67f_11eb_bec6_3c7c3f5d70b1row0_col1,#T_85e295fe_d67f_11eb_bec6_3c7c3f5d70b1row1_col0{
#             background-color:  #d8dce2;
#             color:  #000000;
#         }</style><table id="T_85e295fe_d67f_11eb_bec6_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_cases</th>        <th class="col_heading level0 col1" >hosp_patients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_85e295fe_d67f_11eb_bec6_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >total_cases</th>
#                         <td id="T_85e295fe_d67f_11eb_bec6_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
data_USA.plot(x="date", y=['new_cases', 'hosp_patients'])
plt.title('Plotting new cases and hospital patients in the USA\n', size=15);
plt.xticks(rotation=90)

plt.show()
