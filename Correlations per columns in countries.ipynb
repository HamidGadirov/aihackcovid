# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sb

pd.set_option('display.max_columns', None)

data = pd.read_csv(r"owid-covid-data.csv")
data = data.sort_values('date', ascending=True)
data['date'] = pd.to_datetime(data['date'], format = '%Y-%m-%d')
data_NLD = data[data.iso_code=='NLD']
data_IND = data[data.iso_code=='IND']
data_USA = data[data.iso_code=='USA']
data_BRA = data[data.iso_code=='BRA']
data_NER = data[data.iso_code=='NER']

# %%
### New_cases in correlation to new_vaccinations_smoothed per country ###

# %%
df = data_NLD[['new_cases', 'new_vaccinations_smoothed']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_c38d9d5b_d659_11eb_b37c_3c7c3f5d70b1row0_col0,#T_c38d9d5b_d659_11eb_b37c_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_c38d9d5b_d659_11eb_b37c_3c7c3f5d70b1row0_col1,#T_c38d9d5b_d659_11eb_b37c_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_c38d9d5b_d659_11eb_b37c_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >new_vaccinations_smoothed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c38d9d5b_d659_11eb_b37c_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_c38d9d5b_d659_11eb_b37c_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_c38d9d5b_d659_11eb_b37c_3c7c3f5d70b1row0_col1" class="data row0 col1" >-0.410749</td>
#             </tr>
#             <tr>
#                         <th id="T_c38d9d5b_d659_11eb_b37c_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >new_vaccinations_smoothed</th>
#                         <td id="T_c38d9d5b_d659_11eb_b37c_3c7c3f5d70b1row1_col0" class="data row1 col0" >-0.410749</td>
#                         <td id="T_c38d9d5b_d659_11eb_b37c_3c7c3f5d70b1row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
data_NLD.plot(x="date", y=['new_cases', 'new_vaccinations_smoothed'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new vaccinations smoothed in the Netherlands\n', size=15);
plt.show()

# %%
df = data_IND[['new_cases', 'new_vaccinations_smoothed']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_948a41b4_d659_11eb_bd7d_3c7c3f5d70b1row0_col0,#T_948a41b4_d659_11eb_bd7d_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_948a41b4_d659_11eb_bd7d_3c7c3f5d70b1row0_col1,#T_948a41b4_d659_11eb_bd7d_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_948a41b4_d659_11eb_bd7d_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >new_vaccinations_smoothed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_948a41b4_d659_11eb_bd7d_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_948a41b4_d659_11eb_bd7d_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_948a41b4_d659_11eb_bd7d_3c7c3f5d70b1row0_col1" class="data row0 col1" >0.411153</td>
#             </tr>
#             <tr>
#                         <th id="T_948a41b4_d659_11eb_bd7d_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >new_vaccinations_smoothed</th>
#                         <td id="T_948a41b4_d659_11eb_bd7d_3c7c3f5d70b1row1_col0" class="data row1 col0" >0.411153</td>
#                         <td id="T_948a41b4_d659_11eb_bd7d_3c7c3f5d70b1row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
data_IND.plot(x="date", y=['new_cases', 'new_vaccinations_smoothed'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new vaccinations smoothed in India\n', size=15);
plt.show()

# %%
df = data_USA[['new_cases', 'new_vaccinations_smoothed']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_99858aeb_d659_11eb_8e74_3c7c3f5d70b1row0_col0,#T_99858aeb_d659_11eb_8e74_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_99858aeb_d659_11eb_8e74_3c7c3f5d70b1row0_col1,#T_99858aeb_d659_11eb_8e74_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_99858aeb_d659_11eb_8e74_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >new_vaccinations_smoothed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_99858aeb_d659_11eb_8e74_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_99858aeb_d659_11eb_8e74_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_99858aeb_d659_11eb_8e74_3c7c3f5d70b1row0_col1" class="data row0 col1" >-0.555605</td>
#             </tr>
#             <tr>
#                         <th id="T_99858aeb_d659_11eb_8e74_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >new_vaccinations_smoothed</th>
#                         <td id="T_99858aeb_d659_11eb_8e74_3c7c3f5d70b1row1_col0" class="data row1 col0" >-0.555605</td>
#                         <td id="T_99858aeb_d659_11eb_8e74_3c7c3f5d70b1row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
data_USA.plot(x="date", y=['new_cases', 'new_vaccinations_smoothed'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new vaccinations smoothed in the USA\n', size=15);
plt.show()

# %%
df = data_BRA[['new_cases', 'new_vaccinations_smoothed']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_a0c3284e_d659_11eb_8e72_3c7c3f5d70b1row0_col0,#T_a0c3284e_d659_11eb_8e72_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_a0c3284e_d659_11eb_8e72_3c7c3f5d70b1row0_col1,#T_a0c3284e_d659_11eb_8e72_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_a0c3284e_d659_11eb_8e72_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >new_vaccinations_smoothed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a0c3284e_d659_11eb_8e72_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_a0c3284e_d659_11eb_8e72_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_a0c3284e_d659_11eb_8e72_3c7c3f5d70b1row0_col1" class="data row0 col1" >0.235925</td>
#             </tr>
#             <tr>
#                         <th id="T_a0c3284e_d659_11eb_8e72_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >new_vaccinations_smoothed</th>
#                         <td id="T_a0c3284e_d659_11eb_8e72_3c7c3f5d70b1row1_col0" class="data row1 col0" >0.235925</td>
#                         <td id="T_a0c3284e_d659_11eb_8e72_3c7c3f5d70b1row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
data_BRA.plot(x="date", y=['new_cases', 'new_vaccinations_smoothed'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new vaccinations smoothed in Brazil\n', size=15);
plt.show()

# %%
df = data_NER[['new_cases', 'new_vaccinations_smoothed']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_a5e4b872_d659_11eb_be12_3c7c3f5d70b1row0_col0,#T_a5e4b872_d659_11eb_be12_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_a5e4b872_d659_11eb_be12_3c7c3f5d70b1row0_col1,#T_a5e4b872_d659_11eb_be12_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_a5e4b872_d659_11eb_be12_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >new_vaccinations_smoothed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a5e4b872_d659_11eb_be12_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_a5e4b872_d659_11eb_be12_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_a5e4b872_d659_11eb_be12_3c7c3f5d70b1row0_col1" class="data row0 col1" >0.016462</td>
#             </tr>
#             <tr>
#                         <th id="T_a5e4b872_d659_11eb_be12_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >new_vaccinations_smoothed</th>
#                         <td id="T_a5e4b872_d659_11eb_be12_3c7c3f5d70b1row1_col0" class="data row1 col0" >0.016462</td>
#                         <td id="T_a5e4b872_d659_11eb_be12_3c7c3f5d70b1row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
data_NER.plot(x="date", y=['new_cases', 'new_vaccinations_smoothed'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new vaccinations smoothed in Niger\n', size=15);
plt.show()

# %%
### New_deaths in correlation to new_vaccinations_smoothed per country ###

# %%
df = data_NLD[['new_cases', 'new_deaths']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_04346451_d65a_11eb_ba34_3c7c3f5d70b1row0_col0,#T_04346451_d65a_11eb_ba34_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_04346451_d65a_11eb_ba34_3c7c3f5d70b1row0_col1,#T_04346451_d65a_11eb_ba34_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_04346451_d65a_11eb_ba34_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >new_deaths</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_04346451_d65a_11eb_ba34_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_04346451_d65a_11eb_ba34_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_04346451_d65a_11eb_ba34_3c7c3f5d70b1row0_col1" class="data row0 col1" >0.239612</td>
#             </tr>
#             <tr>
#                         <th id="T_04346451_d65a_11eb_ba34_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >new_deaths</th>
#                         <td id="T_04346451_d65a_11eb_ba34_3c7c3f5d70b1row1_col0" class="data row1 col0" >0.239612</td>
#                         <td id="T_04346451_d65a_11eb_ba34_3c7c3f5d70b1row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
data_NLD.plot(x="date", y=['new_cases', 'new_deaths'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in the Netherlands\n', size=15);
plt.show()

# %%
df = data_IND[['new_cases', 'new_deaths']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_0faa6f1d_d65a_11eb_8300_3c7c3f5d70b1row0_col0,#T_0faa6f1d_d65a_11eb_8300_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_0faa6f1d_d65a_11eb_8300_3c7c3f5d70b1row0_col1,#T_0faa6f1d_d65a_11eb_8300_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_0faa6f1d_d65a_11eb_8300_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >new_deaths</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0faa6f1d_d65a_11eb_8300_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_0faa6f1d_d65a_11eb_8300_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_0faa6f1d_d65a_11eb_8300_3c7c3f5d70b1row0_col1" class="data row0 col1" >0.838743</td>
#             </tr>
#             <tr>
#                         <th id="T_0faa6f1d_d65a_11eb_8300_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >new_deaths</th>
#                         <td id="T_0faa6f1d_d65a_11eb_8300_3c7c3f5d70b1row1_col0" class="data row1 col0" >0.838743</td>
#                         <td id="T_0faa6f1d_d65a_11eb_8300_3c7c3f5d70b1row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
data_IND.plot(x="date", y=['new_cases', 'new_deaths'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in India\n', size=15);
plt.show()

# %%
df = data_USA[['new_cases', 'new_deaths']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_15cb5845_d65a_11eb_b004_3c7c3f5d70b1row0_col0,#T_15cb5845_d65a_11eb_b004_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_15cb5845_d65a_11eb_b004_3c7c3f5d70b1row0_col1,#T_15cb5845_d65a_11eb_b004_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_15cb5845_d65a_11eb_b004_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >new_deaths</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_15cb5845_d65a_11eb_b004_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_15cb5845_d65a_11eb_b004_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_15cb5845_d65a_11eb_b004_3c7c3f5d70b1row0_col1" class="data row0 col1" >0.719885</td>
#             </tr>
#             <tr>
#                         <th id="T_15cb5845_d65a_11eb_b004_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >new_deaths</th>
#                         <td id="T_15cb5845_d65a_11eb_b004_3c7c3f5d70b1row1_col0" class="data row1 col0" >0.719885</td>
#                         <td id="T_15cb5845_d65a_11eb_b004_3c7c3f5d70b1row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
data_USA.plot(x="date", y=['new_cases', 'new_deaths'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in the USA\n', size=15);
plt.show()

# %%
df = data_BRA[['new_cases', 'new_deaths']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_1c65efdc_d65a_11eb_98f3_3c7c3f5d70b1row0_col0,#T_1c65efdc_d65a_11eb_98f3_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_1c65efdc_d65a_11eb_98f3_3c7c3f5d70b1row0_col1,#T_1c65efdc_d65a_11eb_98f3_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_1c65efdc_d65a_11eb_98f3_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >new_deaths</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1c65efdc_d65a_11eb_98f3_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_1c65efdc_d65a_11eb_98f3_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_1c65efdc_d65a_11eb_98f3_3c7c3f5d70b1row0_col1" class="data row0 col1" >0.858044</td>
#             </tr>
#             <tr>
#                         <th id="T_1c65efdc_d65a_11eb_98f3_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >new_deaths</th>
#                         <td id="T_1c65efdc_d65a_11eb_98f3_3c7c3f5d70b1row1_col0" class="data row1 col0" >0.858044</td>
#                         <td id="T_1c65efdc_d65a_11eb_98f3_3c7c3f5d70b1row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
data_BRA.plot(x="date", y=['new_cases', 'new_deaths'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in Brazil\n', size=15);
plt.show()

# %%
df = data_NER[['new_cases', 'new_deaths']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_012ced7e_d65e_11eb_a499_3c7c3f5d70b1row0_col0,#T_012ced7e_d65e_11eb_a499_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_012ced7e_d65e_11eb_a499_3c7c3f5d70b1row0_col1,#T_012ced7e_d65e_11eb_a499_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_012ced7e_d65e_11eb_a499_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >new_deaths</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_012ced7e_d65e_11eb_a499_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_012ced7e_d65e_11eb_a499_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_012ced7e_d65e_11eb_a499_3c7c3f5d70b1row0_col1" class="data row0 col1" >0.492613</td>
#             </tr>
#             <tr>
#                         <th id="T_012ced7e_d65e_11eb_a499_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >new_deaths</th>
#                         <td id="T_012ced7e_d65e_11eb_a499_3c7c3f5d70b1row1_col0" class="data row1 col0" >0.492613</td>
#                         <td id="T_012ced7e_d65e_11eb_a499_3c7c3f5d70b1row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
data_NER.plot(x="date", y=['new_cases', 'new_deaths'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in Niger\n', size=15);
plt.show()

# %%
### New_cases in correlation to icu_patients per country ###

# %%
df = data_NLD[['new_cases', 'icu_patients']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_5e74c637_d65a_11eb_9b87_3c7c3f5d70b1row0_col0,#T_5e74c637_d65a_11eb_9b87_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_5e74c637_d65a_11eb_9b87_3c7c3f5d70b1row0_col1,#T_5e74c637_d65a_11eb_9b87_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_5e74c637_d65a_11eb_9b87_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >icu_patients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5e74c637_d65a_11eb_9b87_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_5e74c637_d65a_11eb_9b87_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_5e74c637_d65a_11eb_9b87_3c7c3f5d70b1row0_col1" class="data row0 col1" >0.433373</td>
#             </tr>
#             <tr>
#                         <th id="T_5e74c637_d65a_11eb_9b87_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >icu_patients</th>
#                         <td id="T_5e74c637_d65a_11eb_9b87_3c7c3f5d70b1row1_col0" class="data row1 col0" >0.433373</td>
#                         <td id="T_5e74c637_d65a_11eb_9b87_3c7c3f5d70b1row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
data_NLD.plot(x="date", y=['new_cases', 'icu_patients'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in the Netherlands\n', size=15);
plt.show()

# %%
df = data_IND[['new_cases', 'icu_patients']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_867a22dd_d65a_11eb_ab4d_3c7c3f5d70b1row0_col0,#T_867a22dd_d65a_11eb_ab4d_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_867a22dd_d65a_11eb_ab4d_3c7c3f5d70b1row0_col1,#T_867a22dd_d65a_11eb_ab4d_3c7c3f5d70b1row1_col1{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }</style><table id="T_867a22dd_d65a_11eb_ab4d_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >icu_patients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_867a22dd_d65a_11eb_ab4d_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_867a22dd_d65a_11eb_ab4d_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_867a22dd_d65a_11eb_ab4d_3c7c3f5d70b1row0_col1" class="data row0 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_867a22dd_d65a_11eb_ab4d_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >icu_patients</th>
#                         <td id="T_867a22dd_d65a_11eb_ab4d_3c7c3f5d70b1row1_col0" class="data row1 col0" >nan</td>
#                         <td id="T_867a22dd_d65a_11eb_ab4d_3c7c3f5d70b1row1_col1" class="data row1 col1" >nan</td>
#             </tr>
#     </tbody></table>

# %%
data_IND.plot(x="date", y=['new_cases', 'icu_patients'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in India\n', size=15);
plt.show()

# %%
df = data_USA[['new_cases', 'icu_patients']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_7eadda7c_d65a_11eb_8939_3c7c3f5d70b1row0_col0,#T_7eadda7c_d65a_11eb_8939_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_7eadda7c_d65a_11eb_8939_3c7c3f5d70b1row0_col1,#T_7eadda7c_d65a_11eb_8939_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_7eadda7c_d65a_11eb_8939_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >icu_patients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7eadda7c_d65a_11eb_8939_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_7eadda7c_d65a_11eb_8939_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_7eadda7c_d65a_11eb_8939_3c7c3f5d70b1row0_col1" class="data row0 col1" >0.921275</td>
#             </tr>
#             <tr>
#                         <th id="T_7eadda7c_d65a_11eb_8939_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >icu_patients</th>
#                         <td id="T_7eadda7c_d65a_11eb_8939_3c7c3f5d70b1row1_col0" class="data row1 col0" >0.921275</td>
#                         <td id="T_7eadda7c_d65a_11eb_8939_3c7c3f5d70b1row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
data_USA.plot(x="date", y=['new_cases', 'icu_patients'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in the USA\n', size=15);
plt.show()

# %%
df = data_BRA[['new_cases', 'icu_patients']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_8384ae67_d65a_11eb_9f26_3c7c3f5d70b1row0_col0,#T_8384ae67_d65a_11eb_9f26_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_8384ae67_d65a_11eb_9f26_3c7c3f5d70b1row0_col1,#T_8384ae67_d65a_11eb_9f26_3c7c3f5d70b1row1_col1{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }</style><table id="T_8384ae67_d65a_11eb_9f26_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >icu_patients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8384ae67_d65a_11eb_9f26_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_8384ae67_d65a_11eb_9f26_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_8384ae67_d65a_11eb_9f26_3c7c3f5d70b1row0_col1" class="data row0 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_8384ae67_d65a_11eb_9f26_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >icu_patients</th>
#                         <td id="T_8384ae67_d65a_11eb_9f26_3c7c3f5d70b1row1_col0" class="data row1 col0" >nan</td>
#                         <td id="T_8384ae67_d65a_11eb_9f26_3c7c3f5d70b1row1_col1" class="data row1 col1" >nan</td>
#             </tr>
#     </tbody></table>

# %%
df = data_NER[['new_cases', 'icu_patients']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_8ab57d8f_d65a_11eb_ac62_3c7c3f5d70b1row0_col0,#T_8ab57d8f_d65a_11eb_ac62_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_8ab57d8f_d65a_11eb_ac62_3c7c3f5d70b1row0_col1,#T_8ab57d8f_d65a_11eb_ac62_3c7c3f5d70b1row1_col1{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }</style><table id="T_8ab57d8f_d65a_11eb_ac62_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >icu_patients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8ab57d8f_d65a_11eb_ac62_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_8ab57d8f_d65a_11eb_ac62_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_8ab57d8f_d65a_11eb_ac62_3c7c3f5d70b1row0_col1" class="data row0 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_8ab57d8f_d65a_11eb_ac62_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >icu_patients</th>
#                         <td id="T_8ab57d8f_d65a_11eb_ac62_3c7c3f5d70b1row1_col0" class="data row1 col0" >nan</td>
#                         <td id="T_8ab57d8f_d65a_11eb_ac62_3c7c3f5d70b1row1_col1" class="data row1 col1" >nan</td>
#             </tr>
#     </tbody></table>

# %%
### New_deaths in correlation to icu_patients per country ###

# %%
df = data_NLD[['new_deaths', 'icu_patients']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_a68f2aba_d65a_11eb_8fc4_3c7c3f5d70b1row0_col0,#T_a68f2aba_d65a_11eb_8fc4_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_a68f2aba_d65a_11eb_8fc4_3c7c3f5d70b1row0_col1,#T_a68f2aba_d65a_11eb_8fc4_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_a68f2aba_d65a_11eb_8fc4_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_deaths</th>        <th class="col_heading level0 col1" >icu_patients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a68f2aba_d65a_11eb_8fc4_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_deaths</th>
#                         <td id="T_a68f2aba_d65a_11eb_8fc4_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_a68f2aba_d65a_11eb_8fc4_3c7c3f5d70b1row0_col1" class="data row0 col1" >0.733445</td>
#             </tr>
#             <tr>
#                         <th id="T_a68f2aba_d65a_11eb_8fc4_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >icu_patients</th>
#                         <td id="T_a68f2aba_d65a_11eb_8fc4_3c7c3f5d70b1row1_col0" class="data row1 col0" >0.733445</td>
#                         <td id="T_a68f2aba_d65a_11eb_8fc4_3c7c3f5d70b1row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
data_NLD.plot(x="date", y=['new_deaths', 'icu_patients'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in the Netherlands\n', size=15);
plt.show()

# %%
df = data_IND[['new_deaths', 'icu_patients']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_b0cf347f_d65a_11eb_8ea7_3c7c3f5d70b1row0_col0,#T_b0cf347f_d65a_11eb_8ea7_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_b0cf347f_d65a_11eb_8ea7_3c7c3f5d70b1row0_col1,#T_b0cf347f_d65a_11eb_8ea7_3c7c3f5d70b1row1_col1{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }</style><table id="T_b0cf347f_d65a_11eb_8ea7_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_deaths</th>        <th class="col_heading level0 col1" >icu_patients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b0cf347f_d65a_11eb_8ea7_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_deaths</th>
#                         <td id="T_b0cf347f_d65a_11eb_8ea7_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_b0cf347f_d65a_11eb_8ea7_3c7c3f5d70b1row0_col1" class="data row0 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_b0cf347f_d65a_11eb_8ea7_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >icu_patients</th>
#                         <td id="T_b0cf347f_d65a_11eb_8ea7_3c7c3f5d70b1row1_col0" class="data row1 col0" >nan</td>
#                         <td id="T_b0cf347f_d65a_11eb_8ea7_3c7c3f5d70b1row1_col1" class="data row1 col1" >nan</td>
#             </tr>
#     </tbody></table>

# %%
df = data_USA[['new_deaths', 'icu_patients']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_b5906a1c_d65a_11eb_b8e7_3c7c3f5d70b1row0_col0,#T_b5906a1c_d65a_11eb_b8e7_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_b5906a1c_d65a_11eb_b8e7_3c7c3f5d70b1row0_col1,#T_b5906a1c_d65a_11eb_b8e7_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_b5906a1c_d65a_11eb_b8e7_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_deaths</th>        <th class="col_heading level0 col1" >icu_patients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b5906a1c_d65a_11eb_b8e7_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_deaths</th>
#                         <td id="T_b5906a1c_d65a_11eb_b8e7_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_b5906a1c_d65a_11eb_b8e7_3c7c3f5d70b1row0_col1" class="data row0 col1" >0.814095</td>
#             </tr>
#             <tr>
#                         <th id="T_b5906a1c_d65a_11eb_b8e7_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >icu_patients</th>
#                         <td id="T_b5906a1c_d65a_11eb_b8e7_3c7c3f5d70b1row1_col0" class="data row1 col0" >0.814095</td>
#                         <td id="T_b5906a1c_d65a_11eb_b8e7_3c7c3f5d70b1row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
data_USA.plot(x="date", y=['new_deaths', 'icu_patients'])
plt.xticks(rotation=90)
plt.title('Plotting new cases and new deaths in the USA\n', size=15);
plt.show()

# %%
df = data_BRA[['new_deaths', 'icu_patients']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_b9226646_d65a_11eb_a7e8_3c7c3f5d70b1row0_col0,#T_b9226646_d65a_11eb_a7e8_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_b9226646_d65a_11eb_a7e8_3c7c3f5d70b1row0_col1,#T_b9226646_d65a_11eb_a7e8_3c7c3f5d70b1row1_col1{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }</style><table id="T_b9226646_d65a_11eb_a7e8_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_deaths</th>        <th class="col_heading level0 col1" >icu_patients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b9226646_d65a_11eb_a7e8_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_deaths</th>
#                         <td id="T_b9226646_d65a_11eb_a7e8_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_b9226646_d65a_11eb_a7e8_3c7c3f5d70b1row0_col1" class="data row0 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_b9226646_d65a_11eb_a7e8_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >icu_patients</th>
#                         <td id="T_b9226646_d65a_11eb_a7e8_3c7c3f5d70b1row1_col0" class="data row1 col0" >nan</td>
#                         <td id="T_b9226646_d65a_11eb_a7e8_3c7c3f5d70b1row1_col1" class="data row1 col1" >nan</td>
#             </tr>
#     </tbody></table>

# %%
df = data_NER[['new_deaths', 'icu_patients']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_bc8eb9da_d65a_11eb_a6fa_3c7c3f5d70b1row0_col0,#T_bc8eb9da_d65a_11eb_a6fa_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_bc8eb9da_d65a_11eb_a6fa_3c7c3f5d70b1row0_col1,#T_bc8eb9da_d65a_11eb_a6fa_3c7c3f5d70b1row1_col1{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }</style><table id="T_bc8eb9da_d65a_11eb_a6fa_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_deaths</th>        <th class="col_heading level0 col1" >icu_patients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bc8eb9da_d65a_11eb_a6fa_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_deaths</th>
#                         <td id="T_bc8eb9da_d65a_11eb_a6fa_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_bc8eb9da_d65a_11eb_a6fa_3c7c3f5d70b1row0_col1" class="data row0 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_bc8eb9da_d65a_11eb_a6fa_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >icu_patients</th>
#                         <td id="T_bc8eb9da_d65a_11eb_a6fa_3c7c3f5d70b1row1_col0" class="data row1 col0" >nan</td>
#                         <td id="T_bc8eb9da_d65a_11eb_a6fa_3c7c3f5d70b1row1_col1" class="data row1 col1" >nan</td>
#             </tr>
#     </tbody></table>

# %%
### New_cases in correlation to stringency_index per country ###

# %%
df = data_NLD[['new_cases', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_d6bcfa30_d65a_11eb_a2a4_3c7c3f5d70b1row0_col0,#T_d6bcfa30_d65a_11eb_a2a4_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_d6bcfa30_d65a_11eb_a2a4_3c7c3f5d70b1row0_col1,#T_d6bcfa30_d65a_11eb_a2a4_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_d6bcfa30_d65a_11eb_a2a4_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d6bcfa30_d65a_11eb_a2a4_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_d6bcfa30_d65a_11eb_a2a4_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_d6bcfa30_d65a_11eb_a2a4_3c7c3f5d70b1row0_col1" class="data row0 col1" >0.410543</td>
#             </tr>
#             <tr>
#                         <th id="T_d6bcfa30_d65a_11eb_a2a4_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >stringency_index</th>
#                         <td id="T_d6bcfa30_d65a_11eb_a2a4_3c7c3f5d70b1row1_col0" class="data row1 col0" >0.410543</td>
#                         <td id="T_d6bcfa30_d65a_11eb_a2a4_3c7c3f5d70b1row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
data_NLD.plot(x="date", y=['new_cases'])
plt.title('Plotting new cases per date in the Netherlands\n', size=15);
data_NLD.plot(x='date', y=['stringency_index'])
plt.title('Plotting stringency index per date in the Netherlands\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
df = data_IND[['new_cases', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_e07c634d_d65a_11eb_be8e_3c7c3f5d70b1row0_col0,#T_e07c634d_d65a_11eb_be8e_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_e07c634d_d65a_11eb_be8e_3c7c3f5d70b1row0_col1,#T_e07c634d_d65a_11eb_be8e_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_e07c634d_d65a_11eb_be8e_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e07c634d_d65a_11eb_be8e_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_e07c634d_d65a_11eb_be8e_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_e07c634d_d65a_11eb_be8e_3c7c3f5d70b1row0_col1" class="data row0 col1" >0.159435</td>
#             </tr>
#             <tr>
#                         <th id="T_e07c634d_d65a_11eb_be8e_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >stringency_index</th>
#                         <td id="T_e07c634d_d65a_11eb_be8e_3c7c3f5d70b1row1_col0" class="data row1 col0" >0.159435</td>
#                         <td id="T_e07c634d_d65a_11eb_be8e_3c7c3f5d70b1row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
data_IND.plot(x="date", y=['new_cases'])
plt.title('Plotting new cases per date in India\n', size=15);
data_IND.plot(x='date', y=['stringency_index'])
plt.title('Plotting stringency index per date in India\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
df = data_USA[['new_cases', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_e59d7e7f_d65a_11eb_a7a9_3c7c3f5d70b1row0_col0,#T_e59d7e7f_d65a_11eb_a7a9_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_e59d7e7f_d65a_11eb_a7a9_3c7c3f5d70b1row0_col1,#T_e59d7e7f_d65a_11eb_a7a9_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_e59d7e7f_d65a_11eb_a7a9_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e59d7e7f_d65a_11eb_a7a9_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_e59d7e7f_d65a_11eb_a7a9_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_e59d7e7f_d65a_11eb_a7a9_3c7c3f5d70b1row0_col1" class="data row0 col1" >0.437947</td>
#             </tr>
#             <tr>
#                         <th id="T_e59d7e7f_d65a_11eb_a7a9_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >stringency_index</th>
#                         <td id="T_e59d7e7f_d65a_11eb_a7a9_3c7c3f5d70b1row1_col0" class="data row1 col0" >0.437947</td>
#                         <td id="T_e59d7e7f_d65a_11eb_a7a9_3c7c3f5d70b1row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
data_USA.plot(x="date", y=['new_cases'])
plt.title('Plotting new cases per date in the USA\n', size=15);
data_USA.plot(x='date', y=['stringency_index'])
plt.title('Plotting stringency index per date in the USA\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
df = data_BRA[['new_cases', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_eba9b6b0_d65a_11eb_bdac_3c7c3f5d70b1row0_col0,#T_eba9b6b0_d65a_11eb_bdac_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_eba9b6b0_d65a_11eb_bdac_3c7c3f5d70b1row0_col1,#T_eba9b6b0_d65a_11eb_bdac_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_eba9b6b0_d65a_11eb_bdac_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_eba9b6b0_d65a_11eb_bdac_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_eba9b6b0_d65a_11eb_bdac_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_eba9b6b0_d65a_11eb_bdac_3c7c3f5d70b1row0_col1" class="data row0 col1" >0.106676</td>
#             </tr>
#             <tr>
#                         <th id="T_eba9b6b0_d65a_11eb_bdac_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >stringency_index</th>
#                         <td id="T_eba9b6b0_d65a_11eb_bdac_3c7c3f5d70b1row1_col0" class="data row1 col0" >0.106676</td>
#                         <td id="T_eba9b6b0_d65a_11eb_bdac_3c7c3f5d70b1row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
data_BRA.plot(x="date", y=['new_cases'])
plt.title('Plotting new cases per date in Brazil\n', size=15);
data_BRA.plot(x='date', y=['stringency_index'])
plt.title('Plotting stringency index per date in Brazil\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
df = data_NER[['new_cases', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_ef70f17d_d65a_11eb_9932_3c7c3f5d70b1row0_col0,#T_ef70f17d_d65a_11eb_9932_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_ef70f17d_d65a_11eb_9932_3c7c3f5d70b1row0_col1,#T_ef70f17d_d65a_11eb_9932_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_ef70f17d_d65a_11eb_9932_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ef70f17d_d65a_11eb_9932_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_ef70f17d_d65a_11eb_9932_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_ef70f17d_d65a_11eb_9932_3c7c3f5d70b1row0_col1" class="data row0 col1" >0.185808</td>
#             </tr>
#             <tr>
#                         <th id="T_ef70f17d_d65a_11eb_9932_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >stringency_index</th>
#                         <td id="T_ef70f17d_d65a_11eb_9932_3c7c3f5d70b1row1_col0" class="data row1 col0" >0.185808</td>
#                         <td id="T_ef70f17d_d65a_11eb_9932_3c7c3f5d70b1row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
data_NER.plot(x="date", y=['new_cases'])
plt.title('Plotting new cases per date in Niger\n', size=15);
data_NER.plot(x='date', y=['stringency_index'])
plt.title('Plotting stringency index per date in Niger\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
### New_deaths in correlation to stringency_index per country ###

# %%
df = data_NLD[['new_deaths', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_0601f659_d65b_11eb_b41e_3c7c3f5d70b1row0_col0,#T_0601f659_d65b_11eb_b41e_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_0601f659_d65b_11eb_b41e_3c7c3f5d70b1row0_col1,#T_0601f659_d65b_11eb_b41e_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_0601f659_d65b_11eb_b41e_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_deaths</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0601f659_d65b_11eb_b41e_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_deaths</th>
#                         <td id="T_0601f659_d65b_11eb_b41e_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_0601f659_d65b_11eb_b41e_3c7c3f5d70b1row0_col1" class="data row0 col1" >0.565288</td>
#             </tr>
#             <tr>
#                         <th id="T_0601f659_d65b_11eb_b41e_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >stringency_index</th>
#                         <td id="T_0601f659_d65b_11eb_b41e_3c7c3f5d70b1row1_col0" class="data row1 col0" >0.565288</td>
#                         <td id="T_0601f659_d65b_11eb_b41e_3c7c3f5d70b1row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
data_NLD.plot(x="date", y=['new_deaths'])
plt.title('Plotting new deaths per date in the Netherlands\n', size=15);
data_NLD.plot(x='date', y=['stringency_index'])
plt.title('Plotting stringency index per date in the Netherlands\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
df = data_IND[['new_deaths', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_0b7b4c24_d65b_11eb_b5f1_3c7c3f5d70b1row0_col0,#T_0b7b4c24_d65b_11eb_b5f1_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_0b7b4c24_d65b_11eb_b5f1_3c7c3f5d70b1row0_col1,#T_0b7b4c24_d65b_11eb_b5f1_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_0b7b4c24_d65b_11eb_b5f1_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_deaths</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0b7b4c24_d65b_11eb_b5f1_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_deaths</th>
#                         <td id="T_0b7b4c24_d65b_11eb_b5f1_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_0b7b4c24_d65b_11eb_b5f1_3c7c3f5d70b1row0_col1" class="data row0 col1" >0.123730</td>
#             </tr>
#             <tr>
#                         <th id="T_0b7b4c24_d65b_11eb_b5f1_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >stringency_index</th>
#                         <td id="T_0b7b4c24_d65b_11eb_b5f1_3c7c3f5d70b1row1_col0" class="data row1 col0" >0.123730</td>
#                         <td id="T_0b7b4c24_d65b_11eb_b5f1_3c7c3f5d70b1row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
data_IND.plot(x="date", y=['new_deaths'])
plt.title('Plotting new deaths per date in India\n', size=15);
data_IND.plot(x='date', y=['stringency_index'])
plt.title('Plotting stringency index per date in India\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
df = data_USA[['new_deaths', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_0f077326_d65b_11eb_a8ce_3c7c3f5d70b1row0_col0,#T_0f077326_d65b_11eb_a8ce_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_0f077326_d65b_11eb_a8ce_3c7c3f5d70b1row0_col1,#T_0f077326_d65b_11eb_a8ce_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_0f077326_d65b_11eb_a8ce_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_deaths</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0f077326_d65b_11eb_a8ce_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_deaths</th>
#                         <td id="T_0f077326_d65b_11eb_a8ce_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_0f077326_d65b_11eb_a8ce_3c7c3f5d70b1row0_col1" class="data row0 col1" >0.481009</td>
#             </tr>
#             <tr>
#                         <th id="T_0f077326_d65b_11eb_a8ce_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >stringency_index</th>
#                         <td id="T_0f077326_d65b_11eb_a8ce_3c7c3f5d70b1row1_col0" class="data row1 col0" >0.481009</td>
#                         <td id="T_0f077326_d65b_11eb_a8ce_3c7c3f5d70b1row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
data_USA.plot(x="date", y=['new_deaths'])
plt.title('Plotting new deaths per date in the USA\n', size=15);
data_USA.plot(x='date', y=['stringency_index'])
plt.title('Plotting stringency index per date in the USA\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
df = data_BRA[['new_deaths', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_136088d9_d65b_11eb_a728_3c7c3f5d70b1row0_col0,#T_136088d9_d65b_11eb_a728_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_136088d9_d65b_11eb_a728_3c7c3f5d70b1row0_col1,#T_136088d9_d65b_11eb_a728_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_136088d9_d65b_11eb_a728_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_deaths</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_136088d9_d65b_11eb_a728_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_deaths</th>
#                         <td id="T_136088d9_d65b_11eb_a728_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_136088d9_d65b_11eb_a728_3c7c3f5d70b1row0_col1" class="data row0 col1" >-0.109759</td>
#             </tr>
#             <tr>
#                         <th id="T_136088d9_d65b_11eb_a728_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >stringency_index</th>
#                         <td id="T_136088d9_d65b_11eb_a728_3c7c3f5d70b1row1_col0" class="data row1 col0" >-0.109759</td>
#                         <td id="T_136088d9_d65b_11eb_a728_3c7c3f5d70b1row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
data_BRA.plot(x="date", y=['new_deaths'])
plt.title('Plotting new deaths per date in Brazil\n', size=15);
data_BRA.plot(x='date', y=['stringency_index'])
plt.title('Plotting stringency index per date in Brazil\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
df = data_NER[['new_deaths', 'stringency_index']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_1806f9a9_d65b_11eb_815b_3c7c3f5d70b1row0_col0,#T_1806f9a9_d65b_11eb_815b_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_1806f9a9_d65b_11eb_815b_3c7c3f5d70b1row0_col1,#T_1806f9a9_d65b_11eb_815b_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_1806f9a9_d65b_11eb_815b_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_deaths</th>        <th class="col_heading level0 col1" >stringency_index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1806f9a9_d65b_11eb_815b_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_deaths</th>
#                         <td id="T_1806f9a9_d65b_11eb_815b_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_1806f9a9_d65b_11eb_815b_3c7c3f5d70b1row0_col1" class="data row0 col1" >0.299162</td>
#             </tr>
#             <tr>
#                         <th id="T_1806f9a9_d65b_11eb_815b_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >stringency_index</th>
#                         <td id="T_1806f9a9_d65b_11eb_815b_3c7c3f5d70b1row1_col0" class="data row1 col0" >0.299162</td>
#                         <td id="T_1806f9a9_d65b_11eb_815b_3c7c3f5d70b1row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
data_NER.plot(x="date", y=['new_deaths'])
plt.title('Plotting new deaths per date in Niger\n', size=15);
data_NER.plot(x='date', y=['stringency_index'])
plt.title('Plotting stringency index per date in Niger\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
### New_cases in correlation to hosp_patients per country ###

# %%
df = data_NLD[['new_cases', 'hosp_patients']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_3606d714_d65b_11eb_9cae_3c7c3f5d70b1row0_col0,#T_3606d714_d65b_11eb_9cae_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_3606d714_d65b_11eb_9cae_3c7c3f5d70b1row0_col1,#T_3606d714_d65b_11eb_9cae_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_3606d714_d65b_11eb_9cae_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >hosp_patients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3606d714_d65b_11eb_9cae_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_3606d714_d65b_11eb_9cae_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_3606d714_d65b_11eb_9cae_3c7c3f5d70b1row0_col1" class="data row0 col1" >0.534663</td>
#             </tr>
#             <tr>
#                         <th id="T_3606d714_d65b_11eb_9cae_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >hosp_patients</th>
#                         <td id="T_3606d714_d65b_11eb_9cae_3c7c3f5d70b1row1_col0" class="data row1 col0" >0.534663</td>
#                         <td id="T_3606d714_d65b_11eb_9cae_3c7c3f5d70b1row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
data_NLD.plot(x="date", y=['new_cases', 'hosp_patients'])
plt.title('Plotting new cases and hospital patients in the Netherlands\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
df = data_IND[['new_cases', 'hosp_patients']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_3d47175a_d65b_11eb_9cad_3c7c3f5d70b1row0_col0,#T_3d47175a_d65b_11eb_9cad_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_3d47175a_d65b_11eb_9cad_3c7c3f5d70b1row0_col1,#T_3d47175a_d65b_11eb_9cad_3c7c3f5d70b1row1_col1{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }</style><table id="T_3d47175a_d65b_11eb_9cad_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >hosp_patients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3d47175a_d65b_11eb_9cad_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_3d47175a_d65b_11eb_9cad_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_3d47175a_d65b_11eb_9cad_3c7c3f5d70b1row0_col1" class="data row0 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_3d47175a_d65b_11eb_9cad_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >hosp_patients</th>
#                         <td id="T_3d47175a_d65b_11eb_9cad_3c7c3f5d70b1row1_col0" class="data row1 col0" >nan</td>
#                         <td id="T_3d47175a_d65b_11eb_9cad_3c7c3f5d70b1row1_col1" class="data row1 col1" >nan</td>
#             </tr>
#     </tbody></table>

# %%
df = data_USA[['new_cases', 'hosp_patients']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_411efd50_d65b_11eb_9cf4_3c7c3f5d70b1row0_col0,#T_411efd50_d65b_11eb_9cf4_3c7c3f5d70b1row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_411efd50_d65b_11eb_9cf4_3c7c3f5d70b1row0_col1,#T_411efd50_d65b_11eb_9cf4_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_411efd50_d65b_11eb_9cf4_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >hosp_patients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_411efd50_d65b_11eb_9cf4_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_411efd50_d65b_11eb_9cf4_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_411efd50_d65b_11eb_9cf4_3c7c3f5d70b1row0_col1" class="data row0 col1" >0.938287</td>
#             </tr>
#             <tr>
#                         <th id="T_411efd50_d65b_11eb_9cf4_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >hosp_patients</th>
#                         <td id="T_411efd50_d65b_11eb_9cf4_3c7c3f5d70b1row1_col0" class="data row1 col0" >0.938287</td>
#                         <td id="T_411efd50_d65b_11eb_9cf4_3c7c3f5d70b1row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
data_USA.plot(x="date", y=['new_cases', 'hosp_patients'])
plt.title('Plotting new cases and hospital patients in the USA\n', size=15);
plt.xticks(rotation=90)

plt.show()

# %%
df = data_BRA[['new_cases', 'hosp_patients']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_46335330_d65b_11eb_832a_3c7c3f5d70b1row0_col0,#T_46335330_d65b_11eb_832a_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_46335330_d65b_11eb_832a_3c7c3f5d70b1row0_col1,#T_46335330_d65b_11eb_832a_3c7c3f5d70b1row1_col1{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }</style><table id="T_46335330_d65b_11eb_832a_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >hosp_patients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_46335330_d65b_11eb_832a_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_46335330_d65b_11eb_832a_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_46335330_d65b_11eb_832a_3c7c3f5d70b1row0_col1" class="data row0 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_46335330_d65b_11eb_832a_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >hosp_patients</th>
#                         <td id="T_46335330_d65b_11eb_832a_3c7c3f5d70b1row1_col0" class="data row1 col0" >nan</td>
#                         <td id="T_46335330_d65b_11eb_832a_3c7c3f5d70b1row1_col1" class="data row1 col1" >nan</td>
#             </tr>
#     </tbody></table>

# %%
df = data_NER[['new_cases', 'hosp_patients']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_4a776776_d65b_11eb_b509_3c7c3f5d70b1row0_col0,#T_4a776776_d65b_11eb_b509_3c7c3f5d70b1row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_4a776776_d65b_11eb_b509_3c7c3f5d70b1row0_col1,#T_4a776776_d65b_11eb_b509_3c7c3f5d70b1row1_col1{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }</style><table id="T_4a776776_d65b_11eb_b509_3c7c3f5d70b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases</th>        <th class="col_heading level0 col1" >hosp_patients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4a776776_d65b_11eb_b509_3c7c3f5d70b1level0_row0" class="row_heading level0 row0" >new_cases</th>
#                         <td id="T_4a776776_d65b_11eb_b509_3c7c3f5d70b1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_4a776776_d65b_11eb_b509_3c7c3f5d70b1row0_col1" class="data row0 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_4a776776_d65b_11eb_b509_3c7c3f5d70b1level0_row1" class="row_heading level0 row1" >hosp_patients</th>
#                         <td id="T_4a776776_d65b_11eb_b509_3c7c3f5d70b1row1_col0" class="data row1 col0" >nan</td>
#                         <td id="T_4a776776_d65b_11eb_b509_3c7c3f5d70b1row1_col1" class="data row1 col1" >nan</td>
#             </tr>
#     </tbody></table>
