# %%
import pandas as pd
owid = pd.read_csv('./covid-19-data-master/public/data/owid-covid-data.csv')
import seaborn as sns
import matplotlib.pyplot as plt
owid
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 98005      ZWE    Africa     Zimbabwe  2021-06-20      41779.0      151.0
# 98006      ZWE    Africa     Zimbabwe  2021-06-21      42195.0      416.0
# 98007      ZWE    Africa     Zimbabwe  2021-06-22      42714.0      519.0
# 98008      ZWE    Africa     Zimbabwe  2021-06-23      43480.0      766.0
# 98009      ZWE    Africa     Zimbabwe  2021-06-24      44306.0      826.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 98005             260.000        1672.0         6.0                5.714  ...
# 98006             302.571        1685.0        13.0                7.143  ...
# 98007             342.286        1691.0         6.0                7.714  ...
# 98008             417.714        1692.0         1.0                7.429  ...
# 98009             482.714        1709.0        17.0                8.857  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0                  NaN                597.029                 9.59
# 1                  NaN                597.029                 9.59
# 2                  NaN                597.029                 9.59
# 3                  NaN                597.029                 9.59
# 4                  NaN                597.029                 9.59
# ...                ...                    ...                  ...
# 98005             21.4                307.846                 1.82
# 98006             21.4                307.846                 1.82
# 98007             21.4                307.846                 1.82
# 98008             21.4                307.846                 1.82
# 98009             21.4                307.846                 1.82
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 0                 NaN           NaN                  37.746
# 1                 NaN           NaN                  37.746
# 2                 NaN           NaN                  37.746
# 3                 NaN           NaN                  37.746
# 4                 NaN           NaN                  37.746
# ...               ...           ...                     ...
# 98005             1.6          30.7                  36.791
# 98006             1.6          30.7                  36.791
# 98007             1.6          30.7                  36.791
# 98008             1.6          30.7                  36.791
# 98009             1.6          30.7                  36.791
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                             0.5            64.83                    0.511
# 1                             0.5            64.83                    0.511
# 2                             0.5            64.83                    0.511
# 3                             0.5            64.83                    0.511
# 4                             0.5            64.83                    0.511
# ...                           ...              ...                      ...
# 98005                         1.7            61.49                    0.571
# 98006                         1.7            61.49                    0.571
# 98007                         1.7            61.49                    0.571
# 98008                         1.7            61.49                    0.571
# 98009                         1.7            61.49                    0.571
#
#        excess_mortality
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 98005               NaN
# 98006               NaN
# 98007               NaN
# 98008               NaN
# 98009               NaN
#
# [98010 rows x 60 columns]

# %%
owid.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
#        'new_vaccinations_smoothed', 'total_vaccinations_per_hundred',
#        'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index', 'excess_mortality'],
#       dtype='object')

# %%
owid.iso_code.unique()
# Out:
# array(['AFG', 'OWID_AFR', 'ALB', 'DZA', 'AND', 'AGO', 'AIA', 'ATG', 'ARG',
#        'ARM', 'ABW', 'OWID_ASI', 'AUS', 'AUT', 'AZE', 'BHS', 'BHR', 'BGD',
#        'BRB', 'BLR', 'BEL', 'BLZ', 'BEN', 'BMU', 'BTN', 'BOL', 'BES',
#        'BIH', 'BWA', 'BRA', 'VGB', 'BRN', 'BGR', 'BFA', 'BDI', 'KHM',
#        'CMR', 'CAN', 'CPV', 'CYM', 'CAF', 'TCD', 'CHL', 'CHN', 'COL',
#        'COM', 'COG', 'COK', 'CRI', 'CIV', 'HRV', 'CUB', 'CUW', 'CYP',
#        'CZE', 'COD', 'DNK', 'DJI', 'DMA', 'DOM', 'ECU', 'EGY', 'SLV',
#        'GNQ', 'ERI', 'EST', 'SWZ', 'ETH', 'OWID_EUR', 'OWID_EUN', 'FRO',
#        'FLK', 'FJI', 'FIN', 'FRA', 'PYF', 'GAB', 'GMB', 'GEO', 'DEU',
#        'GHA', 'GIB', 'GRC', 'GRL', 'GRD', 'GTM', 'GGY', 'GIN', 'GNB',
#        'GUY', 'HTI', 'HND', 'HKG', 'HUN', 'ISL', 'IND', 'IDN', 'OWID_INT',
#        'IRN', 'IRQ', 'IRL', 'IMN', 'ISR', 'ITA', 'JAM', 'JPN', 'JEY',
#        'JOR', 'KAZ', 'KEN', 'KIR', 'OWID_KOS', 'KWT', 'KGZ', 'LAO', 'LVA',
#        'LBN', 'LSO', 'LBR', 'LBY', 'LIE', 'LTU', 'LUX', 'MAC', 'MDG',
#        'MWI', 'MYS', 'MDV', 'MLI', 'MLT', 'MHL', 'MRT', 'MUS', 'MEX',
#        'FSM', 'MDA', 'MCO', 'MNG', 'MNE', 'MSR', 'MAR', 'MOZ', 'MMR',
#        'NAM', 'NRU', 'NPL', 'NLD', 'NCL', 'NZL', 'NIC', 'NER', 'NGA',
#        'OWID_NAM', 'MKD', 'OWID_CYN', 'NOR', 'OWID_OCE', 'OMN', 'PAK',
#        'PSE', 'PAN', 'PNG', 'PRY', 'PER', 'PHL', 'PCN', 'POL', 'PRT',
#        'QAT', 'ROU', 'RUS', 'RWA', 'SHN', 'KNA', 'LCA', 'VCT', 'WSM',
#        'SMR', 'STP', 'SAU', 'SEN', 'SRB', 'SYC', 'SLE', 'SGP', 'SXM',
#        'SVK', 'SVN', 'SLB', 'SOM', 'ZAF', 'OWID_SAM', 'KOR', 'SSD', 'ESP',
#        'LKA', 'SDN', 'SUR', 'SWE', 'CHE', 'SYR', 'TWN', 'TJK', 'TZA',
#        'THA', 'TLS', 'TGO', 'TON', 'TTO', 'TUN', 'TUR', 'TKM', 'TCA',
#        'TUV', 'UGA', 'UKR', 'ARE', 'GBR', 'USA', 'URY', 'UZB', 'VUT',
#        'VAT', 'VEN', 'VNM', 'WLF', 'OWID_WRL', 'YEM', 'ZMB', 'ZWE'],
#       dtype=object)

# %%
df = owid.sort_values('date', ascending=True)
df['date'] = pd.to_datetime(df['date'], format = '%Y-%m-%d')
owid.tail(20)

df_filtered = df[df.iso_code=='NER']
with plt.style.context('fivethirtyeight'):
    df_filtered = df[df.iso_code=='NER']
    df_filtered.plot(x="date", y=["new_cases", "total_cases", "total_cases_per_million"])
    plt.xticks(rotation=90)
    plt.title('Plotting new cases, total cases and total cases per million in the Netherlands\n', size=15);
    plt.show()

# %%
df_neu = df_filtered[df_filtered.date>'2021-04-01']

# %%
# df_filtered = df[df.iso_code=='NER']
with plt.style.context('fivethirtyeight'):
#     df_filtered = df[df.iso_code=='NER']
    df_neu.plot(x="date", y=['people_fully_vaccinated','people_vaccinated','new_vaccinations','new_vaccinations_smoothed'])
    plt.xticks(rotation=90)
    plt.title('Plotting new cases, total cases and total cases per million in the Netherlands\n', size=15);
    plt.show()

# %%
data= df_neu[['new_vaccinations_smoothed','new_cases']]
f, ax= plt.subplots(figsize = (14, 10))

corr = data.corr()
# print(corr)
sns.heatmap(corr,cmap='RdBu', linewidths = 0.05, ax = ax,annot=True)

# 设置Axes的标题
ax.set_title('Correlation between features')
plt.show()

# %%
df_neu.corr()[['new_vaccinations_smoothed']]
# Out:
#                                        new_vaccinations_smoothed
# total_cases                                         5.370875e-01
# new_cases                                           4.071683e-02
# new_cases_smoothed                                 -5.767517e-02
# total_deaths                                        6.601486e-01
# new_deaths                                         -2.179274e-01
# new_deaths_smoothed                                -5.627690e-01
# total_cases_per_million                             5.370858e-01
# new_cases_per_million                               4.074593e-02
# new_cases_smoothed_per_million                     -5.759410e-02
# total_deaths_per_million                            6.599604e-01
# new_deaths_per_million                             -2.179274e-01
# new_deaths_smoothed_per_million                    -5.627690e-01
# reproduction_rate                                  -2.545872e-01
# icu_patients                                                 NaN
# icu_patients_per_million                                     NaN
# hosp_patients                                                NaN
# hosp_patients_per_million                                    NaN
# weekly_icu_admissions                                        NaN
# weekly_icu_admissions_per_million                            NaN
# weekly_hosp_admissions                                       NaN
# weekly_hosp_admissions_per_million                           NaN
# new_tests                                                    NaN
# total_tests                                                  NaN
# total_tests_per_thousand                                     NaN
# new_tests_per_thousand                                       NaN
# new_tests_smoothed                                           NaN
# new_tests_smoothed_per_thousand                              NaN
# positive_rate                                                NaN
# tests_per_case                                               NaN
# total_vaccinations                                  2.222674e-01
# people_vaccinated                                   2.344854e-01
# people_fully_vaccinated                            -7.347516e-01
# new_vaccinations                                             NaN
# new_vaccinations_smoothed                           1.000000e+00
# total_vaccinations_per_hundred                      2.167109e-01
# people_vaccinated_per_hundred                       2.374686e-01
# people_fully_vaccinated_per_hundred                -5.763787e-01
# new_vaccinations_smoothed_per_million               9.999954e-01
# stringency_index                                   -8.035973e-03
# population                                                   NaN
# population_density                                           NaN
# median_age                                         -4.881186e-16
# aged_65_older                                       4.881186e-16
# aged_70_older                                                NaN
# gdp_per_capita                                               NaN
# extreme_poverty                                              NaN
# cardiovasc_death_rate                               4.881186e-16
# diabetes_prevalence                                 5.306088e-16
# female_smokers                                      5.073947e-16
# male_smokers                                        5.306088e-16
# handwashing_facilities                              4.881186e-16
# hospital_beds_per_thousand                         -4.881186e-16
# life_expectancy                                     4.157225e-16
# human_development_index                             5.306088e-16
# excess_mortality                                             NaN

# %%
import scipy 

data = df_neu['new_vaccinations_smoothed']
norm = scipy.stats.norm.cdf(data.dropna())
sns.lineplot(x=data.dropna(),y=norm)
plt.show()
# df_neu[['new_cases','new_vaccinations_smoothed']].plot()

# %%
fig, ax = plt.subplots()
ax2 = ax.twinx()
# n, bins, patches = ax.hist(data, bins=100)
n, bins, patches = ax2.hist(
    data, cumulative=1, histtype='step', bins=100, color='tab:orange')

# %%
import numpy as np
num_bins = 84
data = df_neu['new_vaccinations_smoothed']
# data1 = df_num['total']
data =data.dropna()
counts, bin_edges = np.histogram(data, bins=num_bins, normed=True)
# Choose how many bins you want here
# Use the histogram function to bin the data
counts, bin_edges = np.histogram(data, bins=num_bins, normed=True)
pdf = counts/sum(counts)
# Now find the cdf
cdf = np.cumsum(pdf)

# And finally plot the cdf
plt.plot(bin_edges[1:], cdf)

plt.show()
# counts, bin_edges = np.histogram(data, bins=num_bins, normed=True)
# # Choose how many bins you want here
# # Use the histogram function to bin the data
# counts, bin_edges = np.histogram(data, bins=num_bins, normed=True)
# pdf = counts/sum(counts)
# # Now find the cdf
# cdf = np.cumsum(pdf)

# # And finally plot the cdf
# plt.plot(bin_edges[1:], cdf)

# plt.show()
# Out:
# <ipython-input-26-2397b97ce092>:6: VisibleDeprecationWarning: Passing `normed=True` on non-uniform bins has always been broken, and computes neither the probability density function nor the probability mass function. The result is only correct if the bins are uniform, when density=True will produce the same result anyway. The argument will be removed in a future version of numpy.
#   counts, bin_edges = np.histogram(data, bins=num_bins, normed=True)
# <ipython-input-26-2397b97ce092>:9: VisibleDeprecationWarning: Passing `normed=True` on non-uniform bins has always been broken, and computes neither the probability density function nor the probability mass function. The result is only correct if the bins are uniform, when density=True will produce the same result anyway. The argument will be removed in a future version of numpy.
#   counts, bin_edges = np.histogram(data, bins=num_bins, normed=True)

# %%
# len(df_neu['total_cases'])
# len(df_neu[''])
len(cdf)
np.corrcoef(df_neu['total_cases'],cdf)
# Out:
# array([[1.        , 0.98712209],
#        [0.98712209, 1.        ]])

# %%
 # df_filtered = df[df.iso_code=='NER']
with plt.style.context('fivethirtyeight'):
#     df_filtered = df[df.iso_code=='NER']
    df_neu.plot(x="date", y=['new_vaccinations_smoothed','new_cases'])
    plt.xticks(rotation=90)
    plt.title('Plotting new cases, total cases and total cases per million in the Netherlands\n', size=15);
    plt.show()

# %%
df_neu['new_cases']
# Out:
# 64159     0.0
# 64160     7.0
# 64161    13.0
# 64162     0.0
# 64163     7.0
#          ...
# 64238     0.0
# 64239     0.0
# 64240     0.0
# 64241     3.0
# 64242     3.0
# Name: new_cases, Length: 84, dtype: float64

# %%
df_neu.plot(x="date", y=['total_cases'])
plt.xticks(rotation=90)
plt.title('Plotting new cases, total cases and total cases per million in the Netherlands\n', size=15);
plt.show()

# %%
df_old = df_filtered[df_filtered.date>'2021-01-01']
df_old_2021 = df_old[df_old.date<'2021-04-01']

# %%
df_old_2021.plot(x="date", y=['total_cases'])
plt.xticks(rotation=90)
plt.title('Plotting new cases, total cases and total cases per million in the Netherlands\n', size=15);
plt.show()

# %%
data= df_neu['total_cases'], df_old_2021['total_cases']
f, ax= plt.subplots(figsize = (14, 10))

corr = data.corr()
# print(corr)
sns.heatmap(corr,cmap='RdBu', linewidths = 0.05, ax = ax,annot=True)

ax.set_title('Correlation between features')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-48516bdaec89> in <module>
#       2 f, ax= plt.subplots(figsize = (14, 10))
#       3
# ----> 4 corr = data.corr()
#       5 # print(corr)
#       6 sns.heatmap(corr,cmap='RdBu', linewidths = 0.05, ax = ax,annot=True)
#
# AttributeError: 'tuple' object has no attribute 'corr'

# %%
np.corrcoef(df_old_2021['total_cases'][5:], df_neu['total_cases'])
# Out:
# array([[1.        , 0.95951764],
#        [0.95951764, 1.        ]])

# %%
df = owid.sort_values('date', ascending=True)
df['date'] = pd.to_datetime(df['date'], format = '%Y-%m-%d')
owid.tail(20)

df_filtered = df[df.iso_code=='NLD']
with plt.style.context('fivethirtyeight'):
    df_filtered = df[df.iso_code=='NLD']
    df_filtered.plot(x="date", y=["new_cases", "total_cases", "total_cases_per_million"])
    plt.xticks(rotation=90)
    plt.title('Plotting new cases, total cases and total cases per million in the Netherlands\n', size=15);
    plt.show()

# %%
df_neu = df_filtered[df_filtered.date>'2021-01-01']

# %%
with plt.style.context('fivethirtyeight'):
    df_neu.plot(x="date", y=['new_vaccinations_smoothed'])
    plt.xticks(rotation=90)
    plt.title('Plotting new cases, total cases and total cases per million in the Netherlands\n', size=15);
    plt.show()

# %%
df_old = df_filtered[df_filtered.date>'2021-01-01']
df_old_2021 = df_old[df_old.date<'2021-04-01']

# %%
with plt.style.context('fivethirtyeight'):
    df_neu.plot(x="date", y=['total_cases'])
    plt.xticks(rotation=90)
    plt.title('Plotting new cases, total cases and total cases per million in the Netherlands\n', size=15);
    plt.show()

# %%
df = owid.sort_values('date', ascending=True)
df['date'] = pd.to_datetime(df['date'], format = '%Y-%m-%d')
owid.tail(20)

df_filtered = df[df.iso_code=='IND']
with plt.style.context('fivethirtyeight'):
    df_filtered = df[df.iso_code=='IND']
    df_filtered.plot(x="date", y=["new_cases_per_million"])
    plt.xticks(rotation=90)
    plt.title('Plotting new cases, total cases and total cases per million in India\n', size=15);
    plt.show()

# %%
df = owid.sort_values('date', ascending=True)
df['date'] = pd.to_datetime(df['date'], format = '%Y-%m-%d')
owid.tail(20)

df_filtered = df[df.iso_code=='NLD']
with plt.style.context('fivethirtyeight'):
    df_filtered = df[df.iso_code=='NLD']
    df_filtered.plot(x="date", y=["new_cases_per_million"])
    plt.xticks(rotation=90)
    plt.title('Plotting new cases, total cases and total cases per million in the Netherlands\n', size=15);
    plt.show()

# %%
df = owid.sort_values('date', ascending=True)
df['date'] = pd.to_datetime(df['date'], format = '%Y-%m-%d')
owid.tail(20)

df_filtered = df[df.iso_code=='NLD']
with plt.style.context('fivethirtyeight'):
    df_filtered = df[df.iso_code=='NLD']
    df_filtered.plot(x="date", y=["total_deaths_per_million"])
    plt.xticks(rotation=90)
    plt.title('Plotting new cases, total cases and total cases per million in the Netherlands\n', size=15);
    plt.show()

# %%
df = owid.sort_values('date', ascending=True)
df['date'] = pd.to_datetime(df['date'], format = '%Y-%m-%d')
owid.tail(20)

df_filtered = df[df.iso_code=='IND']
with plt.style.context('fivethirtyeight'):
    df_filtered = df[df.iso_code=='IND']
    df_filtered.plot(x="date", y=["total_deaths_per_million"])
    plt.xticks(rotation=90)
    plt.title('Plotting new cases, total cases and total cases per million in the India\n', size=15);
    plt.show()

# %%
df = owid.sort_values('date', ascending=True)
df['date'] = pd.to_datetime(df['date'], format = '%Y-%m-%d')
owid.tail(20)

df_filtered = df[df.iso_code=='HUN']
with plt.style.context('fivethirtyeight'):
    df_filtered = df[df.iso_code=='HUN']
    df_filtered.plot(x="date", y=["new_cases_per_million"])
    plt.xticks(rotation=90)
    plt.title('Plotting new cases, total cases and total cases per million in Hungary\n', size=15);
    plt.show()

# %%
df = owid.sort_values('date', ascending=True)
df['date'] = pd.to_datetime(df['date'], format = '%Y-%m-%d')
owid.tail(20)

df_filtered = df[df.iso_code=='HUN']
with plt.style.context('fivethirtyeight'):
    df_filtered = df[df.iso_code=='HUN']
    df_filtered.plot(x="date", y=["new_tests_smoothed"])
    plt.xticks(rotation=90)
    plt.title('Plotting new cases, total cases and total cases per million in Hungary\n', size=15);
    plt.show()

# %%
df = owid.sort_values('date', ascending=True)
df['date'] = pd.to_datetime(df['date'], format = '%Y-%m-%d')
owid.tail(20)

with plt.style.context('fivethirtyeight'):
    df_filtered = df[df.iso_code=='NLD']
    df_filtered.plot(x="date", y=["new_tests_smoothed"])
    plt.xticks(rotation=90)
    plt.title('Plotting new_tests_smoothed in NL\n', size=15);
    plt.show()

# %%
df_NL = df[df.iso_code=='NLD']
df_HUN = df[df.iso_code=='HUN']
df_IND = df[df.iso_code=='IND']

df_NL_new_tests_smoothed = df_NL['new_tests_smoothed'].dropna()
df_NL_new_tests_smoothed = df_NL['new_tests_smoothed'].dropna()

df_NL_new_cases_per_million = df_NL['new_cases_per_million'].dropna()
df_HUN_new_cases_per_million = df_HUN['new_cases_per_million'].dropna()

print(len(df_NL_new_tests_smoothed)) # 449
print(len(df_HUN_new_tests_smoothed)) # 466
print(len(df_HUN_new_cases_per_million)) #478

print(np.corrcoef(df_NL_new_tests_smoothed, df_HUN_new_tests_smoothed[17:]))

print(np.corrcoef(df_HUN_new_cases_per_million[12:], df_HUN_new_tests_smoothed))
# Out:
# 449
# 466
# 478
# [[1.         0.79783661]
#  [0.79783661 1.        ]]
# [[1.       0.808006]
#  [0.808006 1.      ]]

# %%
df_NL_new_tests_smoothed.plot(x="date", y=["new_tests_smoothed"])
plt.show()

df_HUN_new_tests_smoothed.plot(x="date", y=["new_tests_smoothed"])
plt.show()
