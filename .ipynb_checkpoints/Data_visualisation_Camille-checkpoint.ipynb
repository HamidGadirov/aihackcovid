# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

pd.set_option('display.max_columns', None)

data = pd.read_csv(r"owid-covid-data.csv")
data = data.sort_values('date', ascending=True)
data['date'] = pd.to_datetime(data['date'], format = '%Y-%m-%d')
data_filtered = data[data.continent=='Europe']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-00e9fa866350> in <module>
#       6 pd.set_option('display.max_columns', None)
#       7
# ----> 8 data = pd.read_csv(r"owid-covid-data.csv")
#       9 data = data.sort_values('date', ascending=True)
#      10 data['date'] = pd.to_datetime(data['date'], format = '%Y-%m-%d')
#
# ...

# %%
plt.style.use('bmh')

fig = plt.subplots(figsize=(12, 8))
ax = sns.scatterplot(data=data_filtered, x='date', y='stringency_index', hue='location')
ax.set_title('Scatterplot people fully vaccinated', size=20)
ax.set_ylim(ymin=0)
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
plt.legend(loc='upper left')
plt.setp(ax.get_xticklabels(), rotation=90)
print()

# %%
data_filtered
# Out:
#       iso_code continent     location       date  total_cases  new_cases  \
# 62211      NLD    Europe  Netherlands 2020-02-27          1.0        1.0
# 62212      NLD    Europe  Netherlands 2020-02-28          1.0        0.0
# 62213      NLD    Europe  Netherlands 2020-02-29          6.0        5.0
# 62214      NLD    Europe  Netherlands 2020-03-01         10.0        4.0
# 62215      NLD    Europe  Netherlands 2020-03-02         18.0        8.0
# ...        ...       ...          ...        ...          ...        ...
# 62690      NLD    Europe  Netherlands 2021-06-20    1706611.0      706.0
# 62691      NLD    Europe  Netherlands 2021-06-21    1707181.0      570.0
# 62692      NLD    Europe  Netherlands 2021-06-22    1707881.0      700.0
# 62693      NLD    Europe  Netherlands 2021-06-23    1708539.0      658.0
# 62694      NLD    Europe  Netherlands 2021-06-24    1709261.0      722.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
corr = data_filtered.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# ...
