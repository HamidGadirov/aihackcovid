# %%
import pandas as pd
import numpy as np
owid = pd.read_csv('./covid-19-data-master/public/data/owid-covid-data.csv', index_col='continent')
import seaborn as sns
import matplotlib.pyplot as plt
# owid

df = owid.sort_values('date', ascending=True)
df['date'] = pd.to_datetime(df['date'], format = '%Y-%m-%d')
owid.tail(20)
# Out:
#           iso_code  location        date  total_cases  new_cases  \
# continent
# Africa         ZWE  Zimbabwe  2021-06-05      39168.0       24.0
# Africa         ZWE  Zimbabwe  2021-06-06      39189.0       21.0
# Africa         ZWE  Zimbabwe  2021-06-07      39238.0       49.0
# Africa         ZWE  Zimbabwe  2021-06-08      39321.0       83.0
# Africa         ZWE  Zimbabwe  2021-06-09      39432.0      111.0
# Africa         ZWE  Zimbabwe  2021-06-10      39496.0       64.0
# Africa         ZWE  Zimbabwe  2021-06-11      39688.0      192.0
# Africa         ZWE  Zimbabwe  2021-06-12      39852.0      164.0
# Africa         ZWE  Zimbabwe  2021-06-13      39959.0      107.0
# Africa         ZWE  Zimbabwe  2021-06-14      40077.0      118.0
# Africa         ZWE  Zimbabwe  2021-06-15      40318.0      241.0
# Africa         ZWE  Zimbabwe  2021-06-16      40556.0      238.0
# Africa         ZWE  Zimbabwe  2021-06-17      40927.0      371.0
# Africa         ZWE  Zimbabwe  2021-06-18      41335.0      408.0
# Africa         ZWE  Zimbabwe  2021-06-19      41628.0      293.0
# Africa         ZWE  Zimbabwe  2021-06-20      41779.0      151.0
# Africa         ZWE  Zimbabwe  2021-06-21      42195.0      416.0
# Africa         ZWE  Zimbabwe  2021-06-22      42714.0      519.0
# Africa         ZWE  Zimbabwe  2021-06-23      43480.0      766.0
# Africa         ZWE  Zimbabwe  2021-06-24      44306.0      826.0
#
#            new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# continent
# Africa                 33.571        1605.0         0.0                1.571
# Africa                 35.000        1606.0         1.0                1.714
# Africa                 39.571        1611.0         5.0                2.429
# Africa                 46.143        1617.0         6.0                2.571
# Africa                 57.286        1622.0         5.0                3.286
# Africa                 57.714        1626.0         4.0                3.143
# Africa                 77.714        1629.0         3.0                3.429
# Africa                 97.714        1632.0         3.0                3.857
# Africa                110.000        1632.0         0.0                3.714
# Africa                119.857        1635.0         3.0                3.429
# Africa                142.429        1637.0         2.0                2.857
# Africa                160.571        1640.0         3.0                2.571
# Africa                204.429        1647.0         7.0                3.000
# Africa                235.286        1656.0         9.0                3.857
# Africa                253.714        1666.0        10.0                4.857
# Africa                260.000        1672.0         6.0                5.714
# Africa                302.571        1685.0        13.0                7.143
# Africa                342.286        1691.0         6.0                7.714
# Africa                417.714        1692.0         1.0                7.429
# Africa                482.714        1709.0        17.0                8.857
#
#            total_cases_per_million  ...  extreme_poverty  \
# continent                           ...
# Africa                    2635.282  ...             21.4
# Africa                    2636.695  ...             21.4
# Africa                    2639.991  ...             21.4
# Africa                    2645.576  ...             21.4
# Africa                    2653.044  ...             21.4
# Africa                    2657.350  ...             21.4
# Africa                    2670.268  ...             21.4
# Africa                    2681.302  ...             21.4
# Africa                    2688.501  ...             21.4
# Africa                    2696.441  ...             21.4
# Africa                    2712.655  ...             21.4
# Africa                    2728.668  ...             21.4
# Africa                    2753.630  ...             21.4
# Africa                    2781.081  ...             21.4
# Africa                    2800.794  ...             21.4
# Africa                    2810.954  ...             21.4
# Africa                    2838.943  ...             21.4
# Africa                    2873.862  ...             21.4
# Africa                    2925.400  ...             21.4
# Africa                    2980.974  ...             21.4
#
#            cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# continent
# Africa                   307.846                 1.82             1.6
# Africa                   307.846                 1.82             1.6
# Africa                   307.846                 1.82             1.6
# Africa                   307.846                 1.82             1.6
# Africa                   307.846                 1.82             1.6
# Africa                   307.846                 1.82             1.6
# Africa                   307.846                 1.82             1.6
# Africa                   307.846                 1.82             1.6
# Africa                   307.846                 1.82             1.6
# Africa                   307.846                 1.82             1.6
# Africa                   307.846                 1.82             1.6
# Africa                   307.846                 1.82             1.6
# Africa                   307.846                 1.82             1.6
# Africa                   307.846                 1.82             1.6
# Africa                   307.846                 1.82             1.6
# Africa                   307.846                 1.82             1.6
# Africa                   307.846                 1.82             1.6
# Africa                   307.846                 1.82             1.6
# Africa                   307.846                 1.82             1.6
# Africa                   307.846                 1.82             1.6
#
#            male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# continent
# Africa             30.7                  36.791                         1.7
# Africa             30.7                  36.791                         1.7
# Africa             30.7                  36.791                         1.7
# Africa             30.7                  36.791                         1.7
# Africa             30.7                  36.791                         1.7
# Africa             30.7                  36.791                         1.7
# Africa             30.7                  36.791                         1.7
# Africa             30.7                  36.791                         1.7
# Africa             30.7                  36.791                         1.7
# Africa             30.7                  36.791                         1.7
# Africa             30.7                  36.791                         1.7
# Africa             30.7                  36.791                         1.7
# Africa             30.7                  36.791                         1.7
# Africa             30.7                  36.791                         1.7
# Africa             30.7                  36.791                         1.7
# Africa             30.7                  36.791                         1.7
# Africa             30.7                  36.791                         1.7
# Africa             30.7                  36.791                         1.7
# Africa             30.7                  36.791                         1.7
# Africa             30.7                  36.791                         1.7
#
#            life_expectancy  human_development_index  excess_mortality
# continent
# Africa               61.49                    0.571               NaN
# Africa               61.49                    0.571               NaN
# Africa               61.49                    0.571               NaN
# Africa               61.49                    0.571               NaN
# Africa               61.49                    0.571               NaN
# Africa               61.49                    0.571               NaN
# Africa               61.49                    0.571               NaN
# Africa               61.49                    0.571               NaN
# Africa               61.49                    0.571               NaN
# Africa               61.49                    0.571               NaN
# Africa               61.49                    0.571               NaN
# Africa               61.49                    0.571               NaN
# Africa               61.49                    0.571               NaN
# Africa               61.49                    0.571               NaN
# Africa               61.49                    0.571               NaN
# Africa               61.49                    0.571               NaN
# Africa               61.49                    0.571               NaN
# Africa               61.49                    0.571               NaN
# Africa               61.49                    0.571               NaN
# Africa               61.49                    0.571               NaN
#
# [20 rows x 59 columns]

# %%
pd.set_option('display.max_columns', None)

# df_indexed = pd.read_csv('./covid-19-data-master/public/data/owid-covid-data.csv', index_col='continent')
df_indexed = pd.read_csv('./covid-19-data-master/public/data/owid-covid-data.csv')

# Select latest available data
# df_indexed = df_indexed.loc[df_indexed['date'] == '2021-04-01']
df_indexed = df_indexed[df_indexed['date'] > '2021-04-01']

# NLD
# IND
# USA
# BRA
# NER

df_indexed = df_indexed[ (df_indexed.iso_code=='NLD') | (df_indexed.iso_code=='USA') | \
                         (df_indexed.iso_code=='IND') | (df_indexed.iso_code=='BRA') | \
                         (df_indexed.iso_code=='NER') ]
# df_indexed = df_indexed + df_indexed[df_indexed.iso_code=='USA']
# print(df_indexed)

countries = df_indexed['iso_code']
# print(countries)
# countries = df_indexed[df_indexed.iso_code=='NLD'] + df_indexed[df_indexed.iso_code=='USA']
# countries = df_indexed[(df_indexed.iso_code=='NLD') & (df_indexed.iso_code=='IND')]
# data_europe = data_indexed.loc['Europe']

new_cases_per_million = df_indexed['new_cases_per_million']
new_vaccinations_smoothed_per_million = df_indexed['new_vaccinations_smoothed_per_million']
icu_patients_per_million = df_indexed['icu_patients_per_million']
hosp_patients_per_million = df_indexed['hosp_patients_per_million']
median_age = df_indexed['median_age']
aged_65_older = df_indexed['aged_65_older']
human_development_index = df_indexed['human_development_index']
gdp_per_capita = df_indexed['gdp_per_capita']
population_density = df_indexed['population_density']
stringency_index = df_indexed['stringency_index']

df_cases_ = pd.DataFrame({'country':countries,
                       'new_cases_per_million': new_cases_per_million,
                       'new_vaccinations_smoothed_per_million': new_vaccinations_smoothed_per_million,
                          'icu_patients_per_million' : icu_patients_per_million,
                        'hosp_patients_per_million' : hosp_patients_per_million,
                          'median_age': median_age,
                          'aged_65_older': aged_65_older,
                          'human_development_index': human_development_index,
                          'gdp_per_capita': gdp_per_capita,
                          'population_density': population_density,
                        'stringency_index': stringency_index,
                             })
# .dropna()

# df_cases_ = df_cases_.groupby('country').sum()
# print(df_cases_)

df_cases_ = df_cases_.reset_index(drop=True)

# df_cases_.set_index(["country"], inplace = True,
#                     append = True, drop = True)

# print(df_cases_.country.unique())

corr = df_cases_.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
#     #T_a59200f6_d71b_11eb_842c_8d164086f33arow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow0_col1 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow0_col2 {
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow0_col3 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow0_col4 {
#             background-color:  #f18f71;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow0_col5 {
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow0_col6 {
#             background-color:  #f49a7b;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow0_col7 {
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow0_col8 {
#             background-color:  #f6bea4;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow0_col9 {
#             background-color:  #ed8366;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow1_col0 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow1_col2 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow1_col3 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow1_col4 {
#             background-color:  #d24b40;
#             color:  #f1f1f1;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow1_col5 {
#             background-color:  #cf453c;
#             color:  #f1f1f1;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow1_col6 {
#             background-color:  #d1493f;
#             color:  #f1f1f1;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow1_col7 {
#             background-color:  #d75445;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow1_col8 {
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow1_col9 {
#             background-color:  #f7af91;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow2_col0 {
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow2_col1 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow2_col3 {
#             background-color:  #e7745b;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow2_col4 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow2_col5 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow2_col6 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow2_col7 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow2_col8 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow2_col9 {
#             background-color:  #de614d;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow3_col0 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow3_col1 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow3_col2 {
#             background-color:  #e7745b;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow3_col4 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow3_col5 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow3_col6 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow3_col7 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow3_col8 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow3_col9 {
#             background-color:  #edd2c3;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow4_col0 {
#             background-color:  #f18f71;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow4_col1 {
#             background-color:  #d24b40;
#             color:  #f1f1f1;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow4_col2 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow4_col3 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow4_col5 {
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow4_col6 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow4_col7 {
#             background-color:  #cf453c;
#             color:  #f1f1f1;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow4_col8 {
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow4_col9 {
#             background-color:  #e9785d;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow5_col0 {
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow5_col1 {
#             background-color:  #cf453c;
#             color:  #f1f1f1;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow5_col2 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow5_col3 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow5_col4 {
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow5_col6 {
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow5_col7 {
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow5_col8 {
#             background-color:  #f7b396;
#             color:  #000000;
#         }    #T_a59200f6_d71b_11eb_842c_8d164086f33arow5_col9 {
#             background-color:  #f7a889;
#             color:  #000000;

# %%
pd.set_option('display.max_columns', None)

# df_indexed = pd.read_csv('./covid-19-data-master/public/data/owid-covid-data.csv', index_col='continent')
df_indexed = pd.read_csv('./covid-19-data-master/public/data/owid-covid-data.csv')

# Select latest available data
# df_indexed = df_indexed.loc[df_indexed['date'] == '2021-04-01']
df_indexed = df_indexed[df_indexed['date'] > '2021-04-01']

# NLD
# IND
# USA
# BRA
# NER

df_indexed = df_indexed[ (df_indexed.iso_code=='NLD') | (df_indexed.iso_code=='USA') | \
                         (df_indexed.iso_code=='IND') | (df_indexed.iso_code=='BRA') | \
                         (df_indexed.iso_code=='NER') ]
# df_indexed = df_indexed + df_indexed[df_indexed.iso_code=='USA']
# print(df_indexed)

countries = df_indexed['iso_code']
# print(countries)
# countries = df_indexed[df_indexed.iso_code=='NLD'] + df_indexed[df_indexed.iso_code=='USA']
# countries = df_indexed[(df_indexed.iso_code=='NLD') & (df_indexed.iso_code=='IND')]
# data_europe = data_indexed.loc['Europe']

df_indexed_NLD = df_indexed[ (df_indexed.iso_code=='NLD') ]
new_cases_per_million_NLD = df_indexed_NLD['new_cases_per_million']

df_indexed_IND = df_indexed[ (df_indexed.iso_code=='IND') ]
new_cases_per_million_IND = df_indexed_IND['new_cases_per_million']

df_indexed_USA = df_indexed[ (df_indexed.iso_code=='USA') ]
new_cases_per_million_USA = df_indexed_USA['new_cases_per_million']

df_indexed_BRA = df_indexed[ (df_indexed.iso_code=='BRA') ]
new_cases_per_million_BRA = df_indexed_BRA['new_cases_per_million']

df_indexed_NER = df_indexed[ (df_indexed.iso_code=='NER') ]
new_cases_per_million_NER = df_indexed_NER['new_cases_per_million']

df_cases_ = pd.DataFrame({
                       'new_cases_per_million_NLD': new_cases_per_million_NLD.to_numpy(),
                        'new_cases_per_million_IND': new_cases_per_million_IND.to_numpy(),
                        'new_cases_per_million_USA': new_cases_per_million_USA.to_numpy(),
                        'new_cases_per_million_BRA': new_cases_per_million_BRA.to_numpy(),
                        'new_cases_per_million_NER': new_cases_per_million_NER.to_numpy(),
                             })

df_cases_ = df_cases_.reset_index(drop=True)

# df_cases_.set_index(["country"], inplace = True,
#                     append = True, drop = True)

# print(df_cases_.country.unique())
# df_cases_
corr = df_cases_.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
#     #T_c4359fcc_d71b_11eb_842c_8d164086f33arow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c4359fcc_d71b_11eb_842c_8d164086f33arow0_col1 {
#             background-color:  #e67259;
#             color:  #000000;
#         }    #T_c4359fcc_d71b_11eb_842c_8d164086f33arow0_col2 {
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }    #T_c4359fcc_d71b_11eb_842c_8d164086f33arow0_col3 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_c4359fcc_d71b_11eb_842c_8d164086f33arow0_col4 {
#             background-color:  #f6bda2;
#             color:  #000000;
#         }    #T_c4359fcc_d71b_11eb_842c_8d164086f33arow1_col0 {
#             background-color:  #e67259;
#             color:  #000000;
#         }    #T_c4359fcc_d71b_11eb_842c_8d164086f33arow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c4359fcc_d71b_11eb_842c_8d164086f33arow1_col2 {
#             background-color:  #f7b093;
#             color:  #000000;
#         }    #T_c4359fcc_d71b_11eb_842c_8d164086f33arow1_col3 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_c4359fcc_d71b_11eb_842c_8d164086f33arow1_col4 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_c4359fcc_d71b_11eb_842c_8d164086f33arow2_col0 {
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }    #T_c4359fcc_d71b_11eb_842c_8d164086f33arow2_col1 {
#             background-color:  #f7b093;
#             color:  #000000;
#         }    #T_c4359fcc_d71b_11eb_842c_8d164086f33arow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c4359fcc_d71b_11eb_842c_8d164086f33arow2_col3 {
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }    #T_c4359fcc_d71b_11eb_842c_8d164086f33arow2_col4 {
#             background-color:  #ecd3c5;
#             color:  #000000;
#         }    #T_c4359fcc_d71b_11eb_842c_8d164086f33arow3_col0 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_c4359fcc_d71b_11eb_842c_8d164086f33arow3_col1 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_c4359fcc_d71b_11eb_842c_8d164086f33arow3_col2 {
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }    #T_c4359fcc_d71b_11eb_842c_8d164086f33arow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c4359fcc_d71b_11eb_842c_8d164086f33arow3_col4 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_c4359fcc_d71b_11eb_842c_8d164086f33arow4_col0 {
#             background-color:  #f6bda2;
#             color:  #000000;
#         }    #T_c4359fcc_d71b_11eb_842c_8d164086f33arow4_col1 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_c4359fcc_d71b_11eb_842c_8d164086f33arow4_col2 {
#             background-color:  #ecd3c5;
#             color:  #000000;
#         }    #T_c4359fcc_d71b_11eb_842c_8d164086f33arow4_col3 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_c4359fcc_d71b_11eb_842c_8d164086f33arow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_c4359fcc_d71b_11eb_842c_8d164086f33a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases_per_million_NLD</th>        <th class="col_heading level0 col1" >new_cases_per_million_IND</th>        <th class="col_heading level0 col2" >new_cases_per_million_USA</th>        <th class="col_heading level0 col3" >new_cases_per_million_BRA</th>        <th class="col_heading level0 col4" >new_cases_per_million_NER</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c4359fcc_d71b_11eb_842c_8d164086f33alevel0_row0" class="row_heading level0 row0" >new_cases_per_million_NLD</th>
#                         <td id="T_c4359fcc_d71b_11eb_842c_8d164086f33arow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_c4359fcc_d71b_11eb_842c_8d164086f33arow0_col1" class="data row0 col1" >0.679305</td>
#                         <td id="T_c4359fcc_d71b_11eb_842c_8d164086f33arow0_col2" class="data row0 col2" >0.839510</td>
#                         <td id="T_c4359fcc_d71b_11eb_842c_8d164086f33arow0_col3" class="data row0 col3" >-0.094791</td>
#                         <td id="T_c4359fcc_d71b_11eb_842c_8d164086f33arow0_col4" class="data row0 col4" >0.298721</td>
#             </tr>
#             <tr>
#                         <th id="T_c4359fcc_d71b_11eb_842c_8d164086f33alevel0_row1" class="row_heading level0 row1" >new_cases_per_million_IND</th>
#                         <td id="T_c4359fcc_d71b_11eb_842c_8d164086f33arow1_col0" class="data row1 col0" >0.679305</td>
#                         <td id="T_c4359fcc_d71b_11eb_842c_8d164086f33arow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_c4359fcc_d71b_11eb_842c_8d164086f33arow1_col2" class="data row1 col2" >0.376930</td>
#                         <td id="T_c4359fcc_d71b_11eb_842c_8d164086f33arow1_col3" class="data row1 col3" >-0.099431</td>
#                         <td id="T_c4359fcc_d71b_11eb_842c_8d164086f33arow1_col4" class="data row1 col4" >0.282457</td>
#             </tr>
#             <tr>
#                         <th id="T_c4359fcc_d71b_11eb_842c_8d164086f33alevel0_row2" class="row_heading level0 row2" >new_cases_per_million_USA</th>
#                         <td id="T_c4359fcc_d71b_11eb_842c_8d164086f33arow2_col0" class="data row2 col0" >0.839510</td>
#                         <td id="T_c4359fcc_d71b_11eb_842c_8d164086f33arow2_col1" class="data row2 col1" >0.376930</td>
#                         <td id="T_c4359fcc_d71b_11eb_842c_8d164086f33arow2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_c4359fcc_d71b_11eb_842c_8d164086f33arow2_col3" class="data row2 col3" >0.078713</td>
#                         <td id="T_c4359fcc_d71b_11eb_842c_8d164086f33arow2_col4" class="data row2 col4" >0.125803</td>
#             </tr>
#             <tr>
#                         <th id="T_c4359fcc_d71b_11eb_842c_8d164086f33alevel0_row3" class="row_heading level0 row3" >new_cases_per_million_BRA</th>
#                         <td id="T_c4359fcc_d71b_11eb_842c_8d164086f33arow3_col0" class="data row3 col0" >-0.094791</td>
#                         <td id="T_c4359fcc_d71b_11eb_842c_8d164086f33arow3_col1" class="data row3 col1" >-0.099431</td>
#                         <td id="T_c4359fcc_d71b_11eb_842c_8d164086f33arow3_col2" class="data row3 col2" >0.078713</td>
#                         <td id="T_c4359fcc_d71b_11eb_842c_8d164086f33arow3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_c4359fcc_d71b_11eb_842c_8d164086f33arow3_col4" class="data row3 col4" >-0.140684</td>
#             </tr>
#             <tr>
#                         <th id="T_c4359fcc_d71b_11eb_842c_8d164086f33alevel0_row4" class="row_heading level0 row4" >new_cases_per_million_NER</th>
#                         <td id="T_c4359fcc_d71b_11eb_842c_8d164086f33arow4_col0" class="data row4 col0" >0.298721</td>
#                         <td id="T_c4359fcc_d71b_11eb_842c_8d164086f33arow4_col1" class="data row4 col1" >0.282457</td>
#                         <td id="T_c4359fcc_d71b_11eb_842c_8d164086f33arow4_col2" class="data row4 col2" >0.125803</td>
#                         <td id="T_c4359fcc_d71b_11eb_842c_8d164086f33arow4_col3" class="data row4 col3" >-0.140684</td>
#                         <td id="T_c4359fcc_d71b_11eb_842c_8d164086f33arow4_col4" class="data row4 col4" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
df_indexed_NLD = df_indexed[ (df_indexed.iso_code=='NLD') ]
new_vaccinations_NLD = df_indexed_NLD['new_vaccinations_smoothed_per_million']

df_indexed_IND = df_indexed[ (df_indexed.iso_code=='IND') ]
new_vaccinations_IND = df_indexed_IND['new_vaccinations_smoothed_per_million']

df_indexed_USA = df_indexed[ (df_indexed.iso_code=='USA') ]
new_vaccinations_USA = df_indexed_USA['new_vaccinations_smoothed_per_million']

df_indexed_BRA = df_indexed[ (df_indexed.iso_code=='BRA') ]
new_vaccinations_BRA = df_indexed_BRA['new_vaccinations_smoothed_per_million']

df_indexed_NER = df_indexed[ (df_indexed.iso_code=='NER') ]
new_vaccinations_NER = df_indexed_NER['new_vaccinations_smoothed_per_million']


df_cases_ = pd.DataFrame({
                       'new_vaccinations_NLD': new_vaccinations_NLD.to_numpy(),
                        'new_vaccinations_IND': new_vaccinations_IND.to_numpy(),
                        'new_vaccinations_USA': new_vaccinations_USA.to_numpy(),
                        'new_vaccinations_BRA': new_vaccinations_BRA.to_numpy(),
                        'new_vaccinations_NER': new_vaccinations_NER.to_numpy(),
                             })
# .dropna()

df_cases_ = df_cases_.reset_index(drop=True)

# df_cases_.set_index(["country"], inplace = True,
#                     append = True, drop = True)

# print(df_cases_.country.unique())
# df_cases_

corr = df_cases_.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow0_col1 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow0_col3 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow0_col4 {
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }    #T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow1_col0 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow1_col2 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow1_col3 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow1_col4 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow2_col1 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow3_col0 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow3_col1 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow3_col2 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow3_col4 {
#             background-color:  #f6bea4;
#             color:  #000000;
#         }    #T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow4_col0 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow4_col2 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow4_col3 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afc" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_vaccinations_NLD</th>        <th class="col_heading level0 col1" >new_vaccinations_IND</th>        <th class="col_heading level0 col2" >new_vaccinations_USA</th>        <th class="col_heading level0 col3" >new_vaccinations_BRA</th>        <th class="col_heading level0 col4" >new_vaccinations_NER</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afclevel0_row0" class="row_heading level0 row0" >new_vaccinations_NLD</th>
#                         <td id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow0_col1" class="data row0 col1" >0.156242</td>
#                         <td id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow0_col2" class="data row0 col2" >-0.776130</td>
#                         <td id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow0_col3" class="data row0 col3" >0.402675</td>
#                         <td id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow0_col4" class="data row0 col4" >0.300270</td>
#             </tr>
#             <tr>
#                         <th id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afclevel0_row1" class="row_heading level0 row1" >new_vaccinations_IND</th>
#                         <td id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow1_col0" class="data row1 col0" >0.156242</td>
#                         <td id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow1_col2" class="data row1 col2" >-0.077380</td>
#                         <td id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow1_col3" class="data row1 col3" >0.329393</td>
#                         <td id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow1_col4" class="data row1 col4" >-0.210309</td>
#             </tr>
#             <tr>
#                         <th id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afclevel0_row2" class="row_heading level0 row2" >new_vaccinations_USA</th>
#                         <td id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow2_col0" class="data row2 col0" >-0.776130</td>
#                         <td id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow2_col1" class="data row2 col1" >-0.077380</td>
#                         <td id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow2_col3" class="data row2 col3" >-0.344941</td>
#                         <td id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow2_col4" class="data row2 col4" >-0.490342</td>
#             </tr>
#             <tr>
#                         <th id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afclevel0_row3" class="row_heading level0 row3" >new_vaccinations_BRA</th>
#                         <td id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow3_col0" class="data row3 col0" >0.402675</td>
#                         <td id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow3_col1" class="data row3 col1" >0.329393</td>
#                         <td id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow3_col2" class="data row3 col2" >-0.344941</td>
#                         <td id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow3_col4" class="data row3 col4" >0.471503</td>
#             </tr>
#             <tr>
#                         <th id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afclevel0_row4" class="row_heading level0 row4" >new_vaccinations_NER</th>
#                         <td id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow4_col0" class="data row4 col0" >0.300270</td>
#                         <td id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow4_col1" class="data row4 col1" >-0.210309</td>
#                         <td id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow4_col2" class="data row4 col2" >-0.490342</td>
#                         <td id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow4_col3" class="data row4 col3" >0.471503</td>
#                         <td id="T_d88ef8e4_d665_11eb_bd2a_8b17a2804afcrow4_col4" class="data row4 col4" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
df_indexed_NLD = df_indexed[ (df_indexed.iso_code=='NLD') ]
stringency_NLD = df_indexed_NLD['stringency_index']

df_indexed_IND = df_indexed[ (df_indexed.iso_code=='IND') ]
stringency_IND = df_indexed_IND['stringency_index']

df_indexed_USA = df_indexed[ (df_indexed.iso_code=='USA') ]
stringency_USA = df_indexed_USA['stringency_index']

df_indexed_BRA = df_indexed[ (df_indexed.iso_code=='BRA') ]
stringency_BRA = df_indexed_BRA['stringency_index']

df_indexed_NER = df_indexed[ (df_indexed.iso_code=='NER') ]
stringency_NER = df_indexed_NER['stringency_index']


df_cases_ = pd.DataFrame({
                       'stringency_NLD': stringency_NLD.to_numpy(),
                        'stringency_IND': stringency_IND.to_numpy(),
                        'stringency_USA': stringency_USA.to_numpy(),
                        'stringency_BRA': stringency_BRA.to_numpy(),
                        'stringency_NER': stringency_NER.to_numpy(),
                             })
# .dropna()

df_cases_ = df_cases_.reset_index(drop=True)

# df_cases_.set_index(["country"], inplace = True,
#                     append = True, drop = True)

# print(df_cases_.country.unique())
# df_cases_
# .isnull().sum()

corr = df_cases_.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow0_col1 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow0_col2 {
#             background-color:  #ec7f63;
#             color:  #000000;
#         }    #T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow0_col3 {
#             background-color:  #f29072;
#             color:  #000000;
#         }    #T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow0_col4 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow2_col0 {
#             background-color:  #ec8165;
#             color:  #000000;
#         }    #T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow2_col3 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow2_col4 {
#             background-color:  #e7745b;
#             color:  #000000;
#         }    #T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow3_col0 {
#             background-color:  #ec7f63;
#             color:  #000000;
#         }    #T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow3_col1 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow3_col2 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow3_col4 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow4_col0 {
#             background-color:  #f39778;
#             color:  #000000;
#         }    #T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow4_col1 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow4_col2 {
#             background-color:  #e36b54;
#             color:  #000000;
#         }    #T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow4_col3 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afc" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >stringency_NLD</th>        <th class="col_heading level0 col1" >stringency_IND</th>        <th class="col_heading level0 col2" >stringency_USA</th>        <th class="col_heading level0 col3" >stringency_BRA</th>        <th class="col_heading level0 col4" >stringency_NER</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afclevel0_row0" class="row_heading level0 row0" >stringency_NLD</th>
#                         <td id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow0_col1" class="data row0 col1" >-0.776138</td>
#                         <td id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow0_col2" class="data row0 col2" >0.653362</td>
#                         <td id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow0_col3" class="data row0 col3" >0.662962</td>
#                         <td id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow0_col4" class="data row0 col4" >0.568871</td>
#             </tr>
#             <tr>
#                         <th id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afclevel0_row1" class="row_heading level0 row1" >stringency_IND</th>
#                         <td id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow1_col0" class="data row1 col0" >-0.776138</td>
#                         <td id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow1_col2" class="data row1 col2" >-0.834049</td>
#                         <td id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow1_col3" class="data row1 col3" >-0.476415</td>
#                         <td id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow1_col4" class="data row1 col4" >-0.634995</td>
#             </tr>
#             <tr>
#                         <th id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afclevel0_row2" class="row_heading level0 row2" >stringency_USA</th>
#                         <td id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow2_col0" class="data row2 col0" >0.653362</td>
#                         <td id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow2_col1" class="data row2 col1" >-0.834049</td>
#                         <td id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow2_col3" class="data row2 col3" >0.152212</td>
#                         <td id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow2_col4" class="data row2 col4" >0.729066</td>
#             </tr>
#             <tr>
#                         <th id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afclevel0_row3" class="row_heading level0 row3" >stringency_BRA</th>
#                         <td id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow3_col0" class="data row3 col0" >0.662962</td>
#                         <td id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow3_col1" class="data row3 col1" >-0.476415</td>
#                         <td id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow3_col2" class="data row3 col2" >0.152212</td>
#                         <td id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow3_col4" class="data row3 col4" >0.317607</td>
#             </tr>
#             <tr>
#                         <th id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afclevel0_row4" class="row_heading level0 row4" >stringency_NER</th>
#                         <td id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow4_col0" class="data row4 col0" >0.568871</td>
#                         <td id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow4_col1" class="data row4 col1" >-0.634995</td>
#                         <td id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow4_col2" class="data row4 col2" >0.729066</td>
#                         <td id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow4_col3" class="data row4 col3" >0.317607</td>
#                         <td id="T_c9c0ce64_d665_11eb_bd2a_8b17a2804afcrow4_col4" class="data row4 col4" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
df_indexed_NLD = df_indexed[ (df_indexed.iso_code=='NLD') ]
new_deaths_per_million_NLD = df_indexed_NLD['new_deaths_per_million']

df_indexed_IND = df_indexed[ (df_indexed.iso_code=='IND') ]
new_deaths_per_million_IND = df_indexed_IND['new_deaths_per_million']

df_indexed_USA = df_indexed[ (df_indexed.iso_code=='USA') ]
new_deaths_per_million_USA = df_indexed_USA['new_deaths_per_million']

df_indexed_BRA = df_indexed[ (df_indexed.iso_code=='BRA') ]
new_deaths_per_million_BRA = df_indexed_BRA['new_deaths_per_million']

df_cases_ = pd.DataFrame({
                       'new_deaths_per_million_NLD': new_deaths_per_million_NLD.to_numpy(),
                        'new_deaths_per_million_IND': new_deaths_per_million_IND.to_numpy(),
                        'new_deaths_per_million_USA': new_deaths_per_million_USA.to_numpy(),
    'new_deaths_per_million_BRA': new_deaths_per_million_BRA.to_numpy(),
                             })

df_cases_ = df_cases_.reset_index(drop=True)

# df_cases_.set_index(["country"], inplace = True,
#                     append = True, drop = True)

# print(df_cases_.country.unique())
# df_cases_
corr = df_cases_.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
#     #T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row0_col1 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row0_col2 {
#             background-color:  #f29072;
#             color:  #000000;
#         }    #T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row0_col3 {
#             background-color:  #f39778;
#             color:  #000000;
#         }    #T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row1_col0 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row1_col2 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row1_col3 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row2_col0 {
#             background-color:  #f29072;
#             color:  #000000;
#         }    #T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row2_col1 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row2_col3 {
#             background-color:  #e67259;
#             color:  #000000;
#         }    #T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row3_col0 {
#             background-color:  #f39778;
#             color:  #000000;
#         }    #T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row3_col1 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row3_col2 {
#             background-color:  #e67259;
#             color:  #000000;
#         }    #T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_deaths_per_million_NLD</th>        <th class="col_heading level0 col1" >new_deaths_per_million_IND</th>        <th class="col_heading level0 col2" >new_deaths_per_million_USA</th>        <th class="col_heading level0 col3" >new_deaths_per_million_BRA</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1level0_row0" class="row_heading level0 row0" >new_deaths_per_million_NLD</th>
#                         <td id="T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row0_col1" class="data row0 col1" >-0.128170</td>
#                         <td id="T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row0_col2" class="data row0 col2" >0.541713</td>
#                         <td id="T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row0_col3" class="data row0 col3" >0.515136</td>
#             </tr>
#             <tr>
#                         <th id="T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1level0_row1" class="row_heading level0 row1" >new_deaths_per_million_IND</th>
#                         <td id="T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row1_col0" class="data row1 col0" >-0.128170</td>
#                         <td id="T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row1_col2" class="data row1 col2" >-0.117921</td>
#                         <td id="T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row1_col3" class="data row1 col3" >-0.222284</td>
#             </tr>
#             <tr>
#                         <th id="T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1level0_row2" class="row_heading level0 row2" >new_deaths_per_million_USA</th>
#                         <td id="T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row2_col0" class="data row2 col0" >0.541713</td>
#                         <td id="T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row2_col1" class="data row2 col1" >-0.117921</td>
#                         <td id="T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row2_col3" class="data row2 col3" >0.676233</td>
#             </tr>
#             <tr>
#                         <th id="T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1level0_row3" class="row_heading level0 row3" >new_deaths_per_million_BRA</th>
#                         <td id="T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row3_col0" class="data row3 col0" >0.515136</td>
#                         <td id="T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row3_col1" class="data row3 col1" >-0.222284</td>
#                         <td id="T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row3_col2" class="data row3 col2" >0.676233</td>
#                         <td id="T_9670e8f8_d68f_11eb_9d1b_ab5e46816eb1row3_col3" class="data row3 col3" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
df_indexed_NLD = df_indexed[ (df_indexed.iso_code=='NLD') ]
total_deaths_per_million_NLD = df_indexed_NLD['total_deaths_per_million']

df_indexed_IND = df_indexed[ (df_indexed.iso_code=='IND') ]
total_deaths_per_million_IND = df_indexed_IND['total_deaths_per_million']

df_indexed_USA = df_indexed[ (df_indexed.iso_code=='USA') ]
total_deaths_per_million_USA = df_indexed_USA['total_deaths_per_million']

df_cases_ = pd.DataFrame({
                       'total_deaths_per_million_NLD': total_deaths_per_million_NLD.to_numpy(),
                        'total_deaths_per_million_IND': total_deaths_per_million_IND.to_numpy(),
                        'total_deaths_per_million_USA': total_deaths_per_million_USA.to_numpy(),
                             })

df_cases_ = df_cases_.reset_index(drop=True)

# df_cases_.set_index(["country"], inplace = True,
#                     append = True, drop = True)

# print(df_cases_.country.unique())
# df_cases_
corr = df_cases_.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
#     #T_09892b8e_d668_11eb_bd2a_8b17a2804afcrow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_09892b8e_d668_11eb_bd2a_8b17a2804afcrow0_col1 {
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }    #T_09892b8e_d668_11eb_bd2a_8b17a2804afcrow0_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_09892b8e_d668_11eb_bd2a_8b17a2804afcrow1_col0 {
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }    #T_09892b8e_d668_11eb_bd2a_8b17a2804afcrow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_09892b8e_d668_11eb_bd2a_8b17a2804afcrow1_col2 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_09892b8e_d668_11eb_bd2a_8b17a2804afcrow2_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_09892b8e_d668_11eb_bd2a_8b17a2804afcrow2_col1 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_09892b8e_d668_11eb_bd2a_8b17a2804afcrow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_09892b8e_d668_11eb_bd2a_8b17a2804afc" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_deaths_per_million_NLD</th>        <th class="col_heading level0 col1" >total_deaths_per_million_IND</th>        <th class="col_heading level0 col2" >total_deaths_per_million_USA</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_09892b8e_d668_11eb_bd2a_8b17a2804afclevel0_row0" class="row_heading level0 row0" >total_deaths_per_million_NLD</th>
#                         <td id="T_09892b8e_d668_11eb_bd2a_8b17a2804afcrow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_09892b8e_d668_11eb_bd2a_8b17a2804afcrow0_col1" class="data row0 col1" >0.954341</td>
#                         <td id="T_09892b8e_d668_11eb_bd2a_8b17a2804afcrow0_col2" class="data row0 col2" >0.993554</td>
#             </tr>
#             <tr>
#                         <th id="T_09892b8e_d668_11eb_bd2a_8b17a2804afclevel0_row1" class="row_heading level0 row1" >total_deaths_per_million_IND</th>
#                         <td id="T_09892b8e_d668_11eb_bd2a_8b17a2804afcrow1_col0" class="data row1 col0" >0.954341</td>
#                         <td id="T_09892b8e_d668_11eb_bd2a_8b17a2804afcrow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_09892b8e_d668_11eb_bd2a_8b17a2804afcrow1_col2" class="data row1 col2" >0.977016</td>
#             </tr>
#             <tr>
#                         <th id="T_09892b8e_d668_11eb_bd2a_8b17a2804afclevel0_row2" class="row_heading level0 row2" >total_deaths_per_million_USA</th>
#                         <td id="T_09892b8e_d668_11eb_bd2a_8b17a2804afcrow2_col0" class="data row2 col0" >0.993554</td>
#                         <td id="T_09892b8e_d668_11eb_bd2a_8b17a2804afcrow2_col1" class="data row2 col1" >0.977016</td>
#                         <td id="T_09892b8e_d668_11eb_bd2a_8b17a2804afcrow2_col2" class="data row2 col2" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
# aged_65_older

df_indexed_NLD = df_indexed[ (df_indexed.iso_code=='NLD') ]
aged_65_older_NLD = df_indexed_NLD['aged_65_older'].dropna()

df_indexed_IND = df_indexed[ (df_indexed.iso_code=='IND') ]
aged_65_older_IND = df_indexed_IND['aged_65_older'].dropna()

df_indexed_USA = df_indexed[ (df_indexed.iso_code=='USA') ]
aged_65_older_USA = df_indexed_USA['aged_65_older'].dropna()

df_indexed_BRA = df_indexed[ (df_indexed.iso_code=='BRA') ]
aged_65_older_BRA = df_indexed_BRA['aged_65_older'].dropna()

df_cases_ = pd.DataFrame({
                       'aged_65_older_NLD': aged_65_older_NLD.to_numpy(),
                        'aged_65_older_IND': aged_65_older_IND.to_numpy(),
                        'aged_65_older_USA': aged_65_older_USA.to_numpy(),
    'aged_65_older_BRA': aged_65_older_BRA.to_numpy(),
                             })

df_cases_ = df_cases_.reset_index(drop=True)

# df_cases_.set_index(["country"], inplace = True,
#                     append = True, drop = True)

# print(df_cases_.country.unique())
print(df_cases_)
# corr = df_cases_.corr()
# corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# 
nld = aged_65_older_NLD.to_numpy()
nld = np.average(nld)
ind = aged_65_older_IND.to_numpy()
ind = np.average(ind)
usa = aged_65_older_USA.to_numpy()
usa = np.average(usa)
bra = aged_65_older_BRA.to_numpy()
bra = np.average(bra)

# df_bar = pd.DataFrame({'aged_65_older_NLD': nld,
#                         'aged_65_older_IND': ind,
#                         'aged_65_older_USA': usa,}, index=0)

df_bar = pd.DataFrame({'countries':['NLD', 'IND', 'USA', 'BRA'], 'val':[nld, ind, usa, bra]})
ax = df_bar.plot.bar(x='countries', y='val', rot=0)
# Out:
#     aged_65_older_NLD  aged_65_older_IND  aged_65_older_USA  aged_65_older_BRA
# 0              18.779              5.989             15.413              8.552
# 1              18.779              5.989             15.413              8.552
# 2              18.779              5.989             15.413              8.552
# 3              18.779              5.989             15.413              8.552
# 4              18.779              5.989             15.413              8.552
# ..                ...                ...                ...                ...
# 79             18.779              5.989             15.413              8.552
# 80             18.779              5.989             15.413              8.552
# 81             18.779              5.989             15.413              8.552
# 82             18.779              5.989             15.413              8.552
# 83             18.779              5.989             15.413              8.552
#
# [84 rows x 4 columns]

# %%
# aged_65_older

df_indexed_NLD = df_indexed[ (df_indexed.iso_code=='NLD') ]
aged_70_older_NLD = df_indexed_NLD['aged_70_older'].dropna()

# print(aged_65_older_NLD)

df_indexed_IND = df_indexed[ (df_indexed.iso_code=='IND') ]
aged_70_older_IND = df_indexed_IND['aged_70_older'].dropna()

# print(aged_65_older_IND)

df_indexed_USA = df_indexed[ (df_indexed.iso_code=='USA') ]
aged_70_older_USA = df_indexed_USA['aged_70_older'].dropna()

# print(aged_65_older_USA)

df_cases_ = pd.DataFrame({
                       'aged_70_older_NLD': aged_70_older_NLD.to_numpy(),
                        'aged_70_older_IND': aged_70_older_IND.to_numpy(),
                        'aged_70_older_USA': aged_70_older_USA.to_numpy(),
                             })

df_cases_ = df_cases_.reset_index(drop=True)

# df_cases_.set_index(["country"], inplace = True,
#                     append = True, drop = True)

# print(df_cases_.country.unique())
print(df_cases_)
corr = df_cases_.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
#     aged_70_older_NLD  aged_70_older_IND  aged_70_older_USA
# 0              11.881              3.414              9.732
# 1              11.881              3.414              9.732
# 2              11.881              3.414              9.732
# 3              11.881              3.414              9.732
# 4              11.881              3.414              9.732
# ..                ...                ...                ...
# 79             11.881              3.414              9.732
# 80             11.881              3.414              9.732
# 81             11.881              3.414              9.732
# 82             11.881              3.414              9.732
# 83             11.881              3.414              9.732
#
# [84 rows x 3 columns]
# <style  type="text/css" >
#     #T_d9e8d4aa_d68b_11eb_9d1b_ab5e46816eb1row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d9e8d4aa_d68b_11eb_9d1b_ab5e46816eb1row0_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d9e8d4aa_d68b_11eb_9d1b_ab5e46816eb1row0_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d9e8d4aa_d68b_11eb_9d1b_ab5e46816eb1row1_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d9e8d4aa_d68b_11eb_9d1b_ab5e46816eb1row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d9e8d4aa_d68b_11eb_9d1b_ab5e46816eb1row1_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d9e8d4aa_d68b_11eb_9d1b_ab5e46816eb1row2_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d9e8d4aa_d68b_11eb_9d1b_ab5e46816eb1row2_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d9e8d4aa_d68b_11eb_9d1b_ab5e46816eb1row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_d9e8d4aa_d68b_11eb_9d1b_ab5e46816eb1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >aged_70_older_NLD</th>        <th class="col_heading level0 col1" >aged_70_older_IND</th>        <th class="col_heading level0 col2" >aged_70_older_USA</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d9e8d4aa_d68b_11eb_9d1b_ab5e46816eb1level0_row0" class="row_heading level0 row0" >aged_70_older_NLD</th>
#                         <td id="T_d9e8d4aa_d68b_11eb_9d1b_ab5e46816eb1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_d9e8d4aa_d68b_11eb_9d1b_ab5e46816eb1row0_col1" class="data row0 col1" >1.000000</td>
#                         <td id="T_d9e8d4aa_d68b_11eb_9d1b_ab5e46816eb1row0_col2" class="data row0 col2" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_d9e8d4aa_d68b_11eb_9d1b_ab5e46816eb1level0_row1" class="row_heading level0 row1" >aged_70_older_IND</th>
#                         <td id="T_d9e8d4aa_d68b_11eb_9d1b_ab5e46816eb1row1_col0" class="data row1 col0" >1.000000</td>
#                         <td id="T_d9e8d4aa_d68b_11eb_9d1b_ab5e46816eb1row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_d9e8d4aa_d68b_11eb_9d1b_ab5e46816eb1row1_col2" class="data row1 col2" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_d9e8d4aa_d68b_11eb_9d1b_ab5e46816eb1level0_row2" class="row_heading level0 row2" >aged_70_older_USA</th>
#                         <td id="T_d9e8d4aa_d68b_11eb_9d1b_ab5e46816eb1row2_col0" class="data row2 col0" >1.000000</td>
#                         <td id="T_d9e8d4aa_d68b_11eb_9d1b_ab5e46816eb1row2_col1" class="data row2 col1" >1.000000</td>
#                         <td id="T_d9e8d4aa_d68b_11eb_9d1b_ab5e46816eb1row2_col2" class="data row2 col2" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
df_indexed_NLD = df_indexed[ (df_indexed.iso_code=='NLD') ]
icu_patients_per_million_NLD = df_indexed_NLD['icu_patients_per_million']

df_indexed_IND = df_indexed[ (df_indexed.iso_code=='IND') ]
icu_patients_per_million_IND = df_indexed_IND['icu_patients_per_million']

df_indexed_USA = df_indexed[ (df_indexed.iso_code=='USA') ]
icu_patients_per_million_USA = df_indexed_USA['icu_patients_per_million']

df_indexed_BRA = df_indexed[ (df_indexed.iso_code=='BRA') ]
icu_patients_per_million_BRA = df_indexed_BRA['icu_patients_per_million']

df_cases_ = pd.DataFrame({
                       'icu_patients_per_million_NLD': icu_patients_per_million_NLD.to_numpy(),
                        'icu_patients_per_million_IND': icu_patients_per_million_IND.to_numpy(),
                        'icu_patients_per_million_USA': icu_patients_per_million_USA.to_numpy(),
    'icu_patients_per_million_BRA': icu_patients_per_million_BRA.to_numpy(),
                             })

df_cases_ = df_cases_.reset_index(drop=True)

# df_cases_.set_index(["country"], inplace = True,
#                     append = True, drop = True)

# print(df_cases_.country.unique())
# df_cases_
corr = df_cases_.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
#     #T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row0_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row0_col2 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row0_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row1_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row1_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row1_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row1_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row2_col0 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row2_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row2_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row3_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row3_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row3_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row3_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }</style><table id="T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >icu_patients_per_million_NLD</th>        <th class="col_heading level0 col1" >icu_patients_per_million_IND</th>        <th class="col_heading level0 col2" >icu_patients_per_million_USA</th>        <th class="col_heading level0 col3" >icu_patients_per_million_BRA</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1level0_row0" class="row_heading level0 row0" >icu_patients_per_million_NLD</th>
#                         <td id="T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row0_col1" class="data row0 col1" >nan</td>
#                         <td id="T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row0_col2" class="data row0 col2" >0.979729</td>
#                         <td id="T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row0_col3" class="data row0 col3" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1level0_row1" class="row_heading level0 row1" >icu_patients_per_million_IND</th>
#                         <td id="T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row1_col0" class="data row1 col0" >nan</td>
#                         <td id="T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row1_col1" class="data row1 col1" >nan</td>
#                         <td id="T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row1_col2" class="data row1 col2" >nan</td>
#                         <td id="T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row1_col3" class="data row1 col3" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1level0_row2" class="row_heading level0 row2" >icu_patients_per_million_USA</th>
#                         <td id="T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row2_col0" class="data row2 col0" >0.979729</td>
#                         <td id="T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row2_col1" class="data row2 col1" >nan</td>
#                         <td id="T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row2_col3" class="data row2 col3" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1level0_row3" class="row_heading level0 row3" >icu_patients_per_million_BRA</th>
#                         <td id="T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row3_col0" class="data row3 col0" >nan</td>
#                         <td id="T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row3_col1" class="data row3 col1" >nan</td>
#                         <td id="T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row3_col2" class="data row3 col2" >nan</td>
#                         <td id="T_189ddcc2_d691_11eb_9d1b_ab5e46816eb1row3_col3" class="data row3 col3" >nan</td>
#             </tr>
#     </tbody></table>

# %%
df_indexed_NLD = df_indexed[ (df_indexed.iso_code=='NLD') ]
hosp_patients_per_million_NLD = df_indexed_NLD['hosp_patients_per_million']

df_indexed_IND = df_indexed[ (df_indexed.iso_code=='IND') ]
hosp_patients_per_million_IND = df_indexed_IND['hosp_patients_per_million']

df_indexed_USA = df_indexed[ (df_indexed.iso_code=='USA') ]
hosp_patients_per_million_USA = df_indexed_USA['hosp_patients_per_million']

df_indexed_BRA = df_indexed[ (df_indexed.iso_code=='BRA') ]
hosp_patients_per_million_BRA = df_indexed_BRA['hosp_patients_per_million']

df_cases_ = pd.DataFrame({
                       'hosp_patients_per_million_NLD': hosp_patients_per_million_NLD.to_numpy(),
                        'hosp_patients_per_million_IND': hosp_patients_per_million_IND.to_numpy(),
                        'hosp_patients_per_million_USA': hosp_patients_per_million_USA.to_numpy(),
    'hosp_patients_per_million_BRA': hosp_patients_per_million_BRA.to_numpy(),
                             })

df_cases_ = df_cases_.reset_index(drop=True)

# df_cases_.set_index(["country"], inplace = True,
#                     append = True, drop = True)

# print(df_cases_.country.unique())
# df_cases_
corr = df_cases_.corr()
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
#     #T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row0_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row0_col2 {
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }    #T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row0_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row1_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row1_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row1_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row1_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row2_col0 {
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }    #T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row2_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row2_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row3_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row3_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row3_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row3_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }</style><table id="T_597dd1de_d691_11eb_9d1b_ab5e46816eb1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >hosp_patients_per_million_NLD</th>        <th class="col_heading level0 col1" >hosp_patients_per_million_IND</th>        <th class="col_heading level0 col2" >hosp_patients_per_million_USA</th>        <th class="col_heading level0 col3" >hosp_patients_per_million_BRA</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_597dd1de_d691_11eb_9d1b_ab5e46816eb1level0_row0" class="row_heading level0 row0" >hosp_patients_per_million_NLD</th>
#                         <td id="T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row0_col1" class="data row0 col1" >nan</td>
#                         <td id="T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row0_col2" class="data row0 col2" >0.947088</td>
#                         <td id="T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row0_col3" class="data row0 col3" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_597dd1de_d691_11eb_9d1b_ab5e46816eb1level0_row1" class="row_heading level0 row1" >hosp_patients_per_million_IND</th>
#                         <td id="T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row1_col0" class="data row1 col0" >nan</td>
#                         <td id="T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row1_col1" class="data row1 col1" >nan</td>
#                         <td id="T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row1_col2" class="data row1 col2" >nan</td>
#                         <td id="T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row1_col3" class="data row1 col3" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_597dd1de_d691_11eb_9d1b_ab5e46816eb1level0_row2" class="row_heading level0 row2" >hosp_patients_per_million_USA</th>
#                         <td id="T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row2_col0" class="data row2 col0" >0.947088</td>
#                         <td id="T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row2_col1" class="data row2 col1" >nan</td>
#                         <td id="T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row2_col3" class="data row2 col3" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_597dd1de_d691_11eb_9d1b_ab5e46816eb1level0_row3" class="row_heading level0 row3" >hosp_patients_per_million_BRA</th>
#                         <td id="T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row3_col0" class="data row3 col0" >nan</td>
#                         <td id="T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row3_col1" class="data row3 col1" >nan</td>
#                         <td id="T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row3_col2" class="data row3 col2" >nan</td>
#                         <td id="T_597dd1de_d691_11eb_9d1b_ab5e46816eb1row3_col3" class="data row3 col3" >nan</td>
#             </tr>
#     </tbody></table>

# %%
# human_development_index - const
# gdp_per_capita - const

df_indexed_NLD = df_indexed[ (df_indexed.iso_code=='NLD') ]
human_development_index_NLD = df_indexed_NLD['human_development_index'].dropna()

df_indexed_IND = df_indexed[ (df_indexed.iso_code=='IND') ]
human_development_index_IND = df_indexed_IND['human_development_index'].dropna()

df_indexed_USA = df_indexed[ (df_indexed.iso_code=='USA') ]
human_development_index_USA = df_indexed_USA['human_development_index'].dropna()

df_indexed_BRA = df_indexed[ (df_indexed.iso_code=='BRA') ]
human_development_index_BRA = df_indexed_BRA['human_development_index'].dropna()

df_cases_ = pd.DataFrame({
                       'human_development_index_NLD': human_development_index_NLD.to_numpy(),
                        'human_development_index_IND': human_development_index_IND.to_numpy(),
                        'human_development_index_USA': human_development_index_USA.to_numpy(),
    'human_development_index_BRA': human_development_index_BRA.to_numpy(),
                             })

df_cases_ = df_cases_.reset_index(drop=True)

# df_cases_.set_index(["country"], inplace = True,
#                     append = True, drop = True)

# print(df_cases_.country.unique())
print(df_cases_)
# corr = df_cases_.corr()
# corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# 
nld = human_development_index_NLD.to_numpy()
nld = np.average(nld)
ind = human_development_index_IND.to_numpy()
ind = np.average(ind)
usa = human_development_index_USA.to_numpy()
usa = np.average(usa)
bra = human_development_index_BRA.to_numpy()
bra = np.average(bra)

# df_bar = pd.DataFrame({'aged_65_older_NLD': nld,
#                         'aged_65_older_IND': ind,
#                         'aged_65_older_USA': usa,}, index=0)

df_bar = pd.DataFrame({'countries':['NLD', 'IND', 'USA', 'BRA'], 'val':[nld, ind, usa, bra]})
ax = df_bar.plot.bar(x='countries', y='val', rot=0)
# Out:
#     human_development_index_NLD  human_development_index_IND  \
# 0                         0.944                        0.645
# 1                         0.944                        0.645
# 2                         0.944                        0.645
# 3                         0.944                        0.645
# 4                         0.944                        0.645
# ..                          ...                          ...
# 79                        0.944                        0.645
# 80                        0.944                        0.645
# 81                        0.944                        0.645
# 82                        0.944                        0.645
# 83                        0.944                        0.645
#
#     human_development_index_USA  human_development_index_BRA
# 0                         0.926                        0.765
# 1                         0.926                        0.765
# 2                         0.926                        0.765
# 3                         0.926                        0.765
# 4                         0.926                        0.765
# ..                          ...                          ...
# 79                        0.926                        0.765
# 80                        0.926                        0.765
# 81                        0.926                        0.765
# 82                        0.926                        0.765
# 83                        0.926                        0.765
#
# [84 rows x 4 columns]

# %%
df_indexed_NLD = df_indexed[ (df_indexed.iso_code=='NLD') ]
new_cases_per_million_NLD = df_indexed_NLD['new_cases_per_million']

df_indexed_IND = df_indexed[ (df_indexed.iso_code=='IND') ]
new_cases_per_million_IND = df_indexed_IND['new_cases_per_million']

df_indexed_USA = df_indexed[ (df_indexed.iso_code=='USA') ]
new_cases_per_million_USA = df_indexed_USA['new_cases_per_million']

df_indexed_BRA = df_indexed[ (df_indexed.iso_code=='BRA') ]
new_cases_per_million_BRA = df_indexed_BRA['new_cases_per_million']

df_indexed_NER = df_indexed[ (df_indexed.iso_code=='NER') ]
new_cases_per_million_NER = df_indexed_NER['new_cases_per_million']

df_cases_ = pd.DataFrame({
                       'new_cases_per_million_NLD': new_cases_per_million_NLD.to_numpy(),
                        'new_cases_per_million_IND': new_cases_per_million_IND.to_numpy(),
                        'new_cases_per_million_USA': new_cases_per_million_USA.to_numpy(),
                        'new_cases_per_million_BRA': new_cases_per_million_BRA.to_numpy(),
                        'new_cases_per_million_NER': new_cases_per_million_NER.to_numpy(),
                             })

df_cases_ = df_cases_.reset_index(drop=True)

# df_cases_.set_index(["country"], inplace = True,
#                     append = True, drop = True)

# print(df_cases_.country.unique())
# df_cases_
corr = df_cases_.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_302507ac_d692_11eb_9d1b_ab5e46816eb1row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_302507ac_d692_11eb_9d1b_ab5e46816eb1row0_col1 {
#             background-color:  #f7a98b;
#             color:  #000000;
#         }    #T_302507ac_d692_11eb_9d1b_ab5e46816eb1row0_col2 {
#             background-color:  #e9785d;
#             color:  #000000;
#         }    #T_302507ac_d692_11eb_9d1b_ab5e46816eb1row0_col3 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_302507ac_d692_11eb_9d1b_ab5e46816eb1row0_col4 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_302507ac_d692_11eb_9d1b_ab5e46816eb1row1_col0 {
#             background-color:  #f7a98b;
#             color:  #000000;
#         }    #T_302507ac_d692_11eb_9d1b_ab5e46816eb1row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_302507ac_d692_11eb_9d1b_ab5e46816eb1row1_col2 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_302507ac_d692_11eb_9d1b_ab5e46816eb1row1_col3 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_302507ac_d692_11eb_9d1b_ab5e46816eb1row1_col4 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_302507ac_d692_11eb_9d1b_ab5e46816eb1row2_col0 {
#             background-color:  #e36b54;
#             color:  #000000;
#         }    #T_302507ac_d692_11eb_9d1b_ab5e46816eb1row2_col1 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_302507ac_d692_11eb_9d1b_ab5e46816eb1row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_302507ac_d692_11eb_9d1b_ab5e46816eb1row2_col3 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_302507ac_d692_11eb_9d1b_ab5e46816eb1row2_col4 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_302507ac_d692_11eb_9d1b_ab5e46816eb1row3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_302507ac_d692_11eb_9d1b_ab5e46816eb1row3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_302507ac_d692_11eb_9d1b_ab5e46816eb1row3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_302507ac_d692_11eb_9d1b_ab5e46816eb1row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_302507ac_d692_11eb_9d1b_ab5e46816eb1row3_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_302507ac_d692_11eb_9d1b_ab5e46816eb1row4_col0 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_302507ac_d692_11eb_9d1b_ab5e46816eb1row4_col1 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_302507ac_d692_11eb_9d1b_ab5e46816eb1row4_col2 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_302507ac_d692_11eb_9d1b_ab5e46816eb1row4_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_302507ac_d692_11eb_9d1b_ab5e46816eb1row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases_per_million_NLD</th>        <th class="col_heading level0 col1" >new_cases_per_million_IND</th>        <th class="col_heading level0 col2" >new_cases_per_million_USA</th>        <th class="col_heading level0 col3" >new_cases_per_million_BRA</th>        <th class="col_heading level0 col4" >new_cases_per_million_NER</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1level0_row0" class="row_heading level0 row0" >new_cases_per_million_NLD</th>
#                         <td id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1row0_col1" class="data row0 col1" >0.679305</td>
#                         <td id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1row0_col2" class="data row0 col2" >0.839510</td>
#                         <td id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1row0_col3" class="data row0 col3" >-0.094791</td>
#                         <td id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1row0_col4" class="data row0 col4" >0.298721</td>
#             </tr>
#             <tr>
#                         <th id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1level0_row1" class="row_heading level0 row1" >new_cases_per_million_IND</th>
#                         <td id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1row1_col0" class="data row1 col0" >0.679305</td>
#                         <td id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1row1_col2" class="data row1 col2" >0.376930</td>
#                         <td id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1row1_col3" class="data row1 col3" >-0.099431</td>
#                         <td id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1row1_col4" class="data row1 col4" >0.282457</td>
#             </tr>
#             <tr>
#                         <th id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1level0_row2" class="row_heading level0 row2" >new_cases_per_million_USA</th>
#                         <td id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1row2_col0" class="data row2 col0" >0.839510</td>
#                         <td id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1row2_col1" class="data row2 col1" >0.376930</td>
#                         <td id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1row2_col3" class="data row2 col3" >0.078713</td>
#                         <td id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1row2_col4" class="data row2 col4" >0.125803</td>
#             </tr>
#             <tr>
#                         <th id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1level0_row3" class="row_heading level0 row3" >new_cases_per_million_BRA</th>
#                         <td id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1row3_col0" class="data row3 col0" >-0.094791</td>
#                         <td id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1row3_col1" class="data row3 col1" >-0.099431</td>
#                         <td id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1row3_col2" class="data row3 col2" >0.078713</td>
#                         <td id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1row3_col4" class="data row3 col4" >-0.140684</td>
#             </tr>
#             <tr>
#                         <th id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1level0_row4" class="row_heading level0 row4" >new_cases_per_million_NER</th>
#                         <td id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1row4_col0" class="data row4 col0" >0.298721</td>
#                         <td id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1row4_col1" class="data row4 col1" >0.282457</td>
#                         <td id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1row4_col2" class="data row4 col2" >0.125803</td>
#                         <td id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1row4_col3" class="data row4 col3" >-0.140684</td>
#                         <td id="T_302507ac_d692_11eb_9d1b_ab5e46816eb1row4_col4" class="data row4 col4" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
import scipy.stats as st

# new_cases_per_million_NLD
# new_cases_per_million_IND
# new_cases_per_million_USA
# new_cases_per_million_BRA
# new_cases_per_million_NER

df_indexed_NLD = df_indexed_NLD.reset_index(drop=True)
df_indexed_IND = df_indexed_IND.reset_index(drop=True)

new_cases_per_million_NLD = df_indexed_NLD['new_cases_per_million']
new_cases_per_million_IND = df_indexed_IND['new_cases_per_million']

# df_bis_smoking.set_index(["country"], inplace = True,
#                     append = True, drop = True)

df_indexed_NLD['new_cases_per_million_bin'] = (new_cases_per_million_NLD > new_cases_per_million_NLD.median())
df_indexed_IND['new_cases_per_million_bin'] = (new_cases_per_million_IND > new_cases_per_million_IND.median())

# print(df_indexed_NLD['new_cases_per_million_bin'])
# print(df_indexed_IND['new_cases_per_million_bin'])

this = pd.crosstab(df_indexed_NLD['new_cases_per_million_bin'], df_indexed_IND['new_cases_per_million_bin'])

# this = pd.crosstab(df_bis_smoking['total_deaths_binarized'], df_bis_smoking['n_smokers_binarized'])
st.chi2_contingency(this)
# Out:
# (80.04761904761905,
#  3.654943097246087e-19,
#  1,
#  array([[21., 21.],
#         [21., 21.]]))
